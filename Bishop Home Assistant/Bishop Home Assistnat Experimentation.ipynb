# %%
import requests
from pprint import pprint

# %% [markdown]
# __Getting Current State:__

# %%
header=headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiIyYzY5MGNjYjdhOGU0OWE0YjMxOTAzN2NlYzllOTBhMCIsImlhdCI6MTcwMTYzODQyMywiZXhwIjoyMDE2OTk4NDIzfQ.RLhj--A53djrBSrKDuRHQQEWUKnvmgF0m0jfaMCCq4Y"
}

# %%
def get_home_status(url="http://homeassistant.local:8123/api/states"):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        current_state= response.json()
        return current_state
        # Convert the list of entities to a dictionary with entity IDs as keys
    else:
        print(f"Error: {response.status_code}")
        print(response.text)

# %%
current_status=get_home_status()
pprint(current_status)
# Out:
# [{'attributes': {'device_trackers': [],
#                  'editable': True,
#                  'friendly_name': 'Luke Hill',
#                  'id': 'luke_hill',
#                  'user_id': '6085dee12d0a47839c51190ef4127c71'},
#   'context': {'id': '01HGRTAKM0M8045GWSNH1218H6',
#               'parent_id': None,
#               'user_id': None},
#   'entity_id': 'person.luke_hill',
#   'last_changed': '2023-12-03T21:45:39.633208+00:00',
#   'last_updated': '2023-12-03T21:46:06.336920+00:00',
#   'state': 'unknown'},
#  {'attributes': {'auto_update': True,
#                  'entity_picture': 'https://brands.home-assistant.io/hassio/icon.png',
#                  'friendly_name': 'Home Assistant Supervisor Update',
#                  'in_progress': False,
#                  'installed_version': '2023.11.6',
#                  'latest_version': '2023.11.6',
#                  'release_summary': None,
# ...

# %%
# Printing Keys
for entity in range(len(current_status)):
    print(current_status[entity])
# Out:
# {'entity_id': 'person.luke_hill', 'state': 'unknown', 'attributes': {'editable': True, 'id': 'luke_hill', 'user_id': '6085dee12d0a47839c51190ef4127c71', 'device_trackers': [], 'friendly_name': 'Luke Hill'}, 'last_changed': '2023-12-03T21:45:39.633208+00:00', 'last_updated': '2023-12-03T21:46:06.336920+00:00', 'context': {'id': '01HGRTAKM0M8045GWSNH1218H6', 'parent_id': None, 'user_id': None}}
# ...

# %%
len(current_status)
# Out:
# 132

# %% [markdown]
# __Pushing requests to Bishop Home Assistant:__

# %%
# Home Assistant API endpoint for turning on a light
url = "http://homeassistant.local:8123/api/services/light/turn_on"

# Headers with authorization and content type
headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiIyYzY5MGNjYjdhOGU0OWE0YjMxOTAzN2NlYzllOTBhMCIsImlhdCI6MTcwMTYzODQyMywiZXhwIjoyMDE2OTk4NDIzfQ.RLhj--A53djrBSrKDuRHQQEWUKnvmgF0m0jfaMCCq4Y"
}

# Data payload for the service call
data = {
    "entity_id": "light.office"  # Replace with the actual entity ID of your light
}

# Make a POST request to the Home Assistant API
response = requests.post(url, json=data, headers=headers)

# Check the response
if response.status_code == 200:
    print("Light turned off successfully!")
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Light turned off successfully!
