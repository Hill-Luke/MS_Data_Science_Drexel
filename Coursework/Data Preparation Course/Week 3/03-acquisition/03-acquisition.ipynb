# %% [markdown]
# # DSCI 511: Data acquisition and pre-processing <br>Chapter 3: Acquiring Data from the Internet
#
# ## 3.1 APIs
# The entire infrastructure of the internet uses three basic ideas as building blocks: clients, servers, and requests. When you visit a website, your web browser is the _client_. In order to display the web page to you, your browser makes a _request_ to a remote _server_. The server then processes the request and sends back the page, which is essentially an HTML document. Your browser can interpret this document, which contains all kinds of information (including styling and presentation-related information and hyperlinks), and display it on your screen.
#
# ### 3.1.1 What is an API?
# An _Application Processing Interface_ (API) allows you to make a request to a remote server to obtain data instead of a web page. So instead of an HTML document, usually an API request will return some data in a format like, JSON, CSV, or XML. To review how to load data from these formats review Chapter 1.

# %% [markdown]
# ### 3.1.2 Accessing APIs
# When you access a web page, your browser makes a request to the remote server. The browser uses a URL address to send the request. Similarly, URLs are also used to send requests to APIs. Usually, constructing the URL needed to send the request is an important early step in working with APIs.
# #### 3.1.2.1 Making Requests and handling JSON responses
# When writing Python code to get data from APIs, we'll use the `requests` module to make these requests. The `requests.get()` method can be supplied with a URL, and returns a "response" object, which has a very convenient `.json()` method to process the response when it is a JSON file and return a dictionary (so we don't necessarily have to use the `json` module to de-serialize a request's text result. For example, we'll use the GitHub API to grab some data about a user.

# %%
import requests
import json
# format: "https://api.github.com/user/USERNAME"
response = requests.get("https://api.github.com/users/jakerylandwilliams")

# json.loads(response.text)

#response.json()
response.json()
# Out:
# {'login': 'jakerylandwilliams',
#  'id': 4721029,
#  'node_id': 'MDQ6VXNlcjQ3MjEwMjk=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/4721029?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jakerylandwilliams',
#  'html_url': 'https://github.com/jakerylandwilliams',
#  'followers_url': 'https://api.github.com/users/jakerylandwilliams/followers',
#  'following_url': 'https://api.github.com/users/jakerylandwilliams/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jakerylandwilliams/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jakerylandwilliams/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jakerylandwilliams/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jakerylandwilliams/orgs',
#  'repos_url': 'https://api.github.com/users/jakerylandwilliams/repos',
#  'events_url': 'https://api.github.com/users/jakerylandwilliams/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jakerylandwilliams/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Jake Williams',
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 7,
#  'public_gists': 0,
#  'followers': 39,
#  'following': 3,
#  'created_at': '2013-06-17T18:27:22Z',
#  'updated_at': '2023-05-05T18:59:29Z'}

# %% [markdown]
# GitHub's API doesn't require an "access token" to return this information about a user. There are thousands of public APIs available on the web that can help you get useful data, and many of them can be used as simply as this GitHub example.
# #### 3.1.2.2 A more local example of an API
# The Southeastern Pennsylvania Transportation Authority (SEPTA) [makes a few APIs available](http://www3.septa.org/hackathon/). Some of these APIs can be used to access realtime data about SEPTA transit (trains, buses, trolleys). For example, we can request data about the next trains to arrive at a given station.

# %%
# format: "http://www3.septa.org/hackathon/Arrivals/*STATION_NAME*/*NUMBER_OF_TRAINS*"
arrivals_response = requests.get("http://www3.septa.org/hackathon/Arrivals/30th Street Station/5")

arrivals_dict = arrivals_response.json()
arrivals_dict
# Out:
# {'Gray 30th Street Departures: October 31, 2023, 9:55 am': [{'Northbound': [{'direction': 'N',
#      'path': 'R4N',
#      'train_id': '420',
#      'origin': 'Airport Terminal E-F',
#      'destination': 'Warminster',
#      'line': 'Warminster',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Penn Medical Station',
#      'sched_time': '2023-10-31 09:59:01.000',
#      'depart_time': '2023-10-31 10:00:00.000',
#      'track': '5',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R5N',
#      'train_id': '6508',
#      'origin': 'Gray 30th Street',
#      'destination': 'Doylestown',
#      'line': 'Lansdale/Doylestown',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': None,
#      'sched_time': '2023-10-31 10:11:01.000',
#      'depart_time': '2023-10-31 10:12:00.000',
#      'track': '1',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R5N',
#      'train_id': '9512',
#      'origin': 'Malvern',
#      'destination': 'Temple U',
#      'line': 'Paoli/Thorndale',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Ardmore',
#      'sched_time': '2023-10-31 10:14:01.000',
#      'depart_time': '2023-10-31 10:15:00.000',
#      'track': '1',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R8/3N',
#      'train_id': '8322',
#      'origin': 'Chestnut Hill West',
#      'destination': 'West Trenton',
#      'line': 'Chestnut Hill West',
#      'status': '1 min',
#      'service_type': 'LOCAL',
#      'next_station': 'Allen Lane',
#      'sched_time': '2023-10-31 10:22:01.000',
#      'depart_time': '2023-10-31 10:23:00.000',
#      'track': '2',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R2/5N',
#      'train_id': '9208',
#      'origin': 'Newark',
#      'destination': 'Temple U',
#      'line': 'Wilmington/Newark',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Crum Lynne',
#      'sched_time': '2023-10-31 10:24:01.000',
#      'depart_time': '2023-10-31 10:25:00.000',
#      'track': '5',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None}]},
#   {'Southbound': [{'direction': 'S',
#      'path': 'R8/4S',
#      'train_id': '8423',
#      'origin': 'Fox Chase',
#      'destination': 'Airport',
#      'line': 'Airport',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': '30th Street Gray',
#      'sched_time': '2023-10-31 09:58:01.000',
#      'depart_time': '2023-10-31 09:59:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R2/3S',
#      'train_id': '2309',
#      'origin': 'Elm St',
#      'destination': 'Wawa',
#      'line': 'Media/Wawa',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Suburban Station',
#      'sched_time': '2023-10-31 10:02:01.000',
#      'depart_time': '2023-10-31 10:03:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R4S',
#      'train_id': '6477',
#      'origin': 'Glenside',
#      'destination': '30th Street Gray',
#      'line': 'Airport',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Suburban Station',
#      'sched_time': '2023-10-31 10:06:01.000',
#      'depart_time': '2023-10-31 10:07:00.000',
#      'track': '',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R4S',
#      'train_id': '425',
#      'origin': 'Warminster',
#      'destination': 'Airport',
#      'line': 'Warminster',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Elkins Park',
#      'sched_time': '2023-10-31 10:28:01.000',
#      'depart_time': '2023-10-31 10:29:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R3/2S',
#      'train_id': '3209',
#      'origin': 'West Trenton',
#      'destination': 'Wilmington',
#      'line': 'West Trenton',
#      'status': '5 min',
#      'service_type': 'LOCAL',
#      'next_station': 'Meadowbrook',
#      'sched_time': '2023-10-31 10:31:01.000',
#      'depart_time': '2023-10-31 10:32:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None}]}]}

# %% [markdown]
# #### 3.1.2.3 Exercise: processing a JSON response
# Make a request to the SEPTA Arrivals API to get data on the next 10 trains to arrive at Suburban Station. Store this JSON-format data into a dictionary. Inspect the dictionary structure. Then, write code to create a list containing 10 dictionaries, one for each train. These new dictionaries should look like this:

# %%
from pprint import pprint
# example of train dictionary format
train_dict = {
    'direction': 'S',
     'line': 'Media/Elwyn',
     'sched_time': '2018-08-22 17:31:01.000',
     'status': 'On Time',
     'track': '6'
}

pprint(train_dict)
# Out:
# {'direction': 'S',
#  'line': 'Media/Elwyn',
#  'sched_time': '2018-08-22 17:31:01.000',
#  'status': 'On Time',
#  'track': '6'}

# %% [markdown]
# __Luke's Notes:__
# When iterating through a nested structure, get the top keys using the following code:

# %%
# Iterating through a nested structure.
arrivals_response = requests.get("http://www3.septa.org/hackathon/Arrivals/Suburban Station/10")
arrivals_dict = arrivals_response.json()
list(arrivals_dict.keys())
# In this case we only have one key, which is the most recent departure.

# Listing the values
list(arrivals_dict.values())
# We have another nexted structure. Here we have a secondary key called 'Northbound' which indicates the direction of the trains.
# Since we have a series of nests here, we'll convert to a list to get the underlying values for the trains
list(arrivals_dict.values())[0][0]['Northbound']


# From here, just pass a loop and use the keys to define the updated values!
# Out:
# [{'direction': 'N',
#   'path': 'R3N',
#   'train_id': '9312',
#   'origin': 'Wawa',
#   'destination': 'Temple U',
#   'line': 'West Trenton',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': 'Suburban Station',
#   'sched_time': '2023-10-31 09:56:00.000',
#   'depart_time': '2023-10-31 09:57:00.000',
#   'track': '2',
#   'track_change': None,
#   'platform': 'A',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R4N',
#   'train_id': '420',
#   'origin': 'Airport Terminal E-F',
#   'destination': 'Warminster',
#   'line': 'Warminster',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': 'Penn Medical Station',
#   'sched_time': '2023-10-31 10:04:00.000',
#   'depart_time': '2023-10-31 10:05:00.000',
#   'track': '2',
#   'track_change': None,
#   'platform': 'A',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R5N',
#   'train_id': '6508',
#   'origin': 'Gray 30th Street',
#   'destination': 'Doylestown',
#   'line': 'Lansdale/Doylestown',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': None,
#   'sched_time': '2023-10-31 10:15:00.000',
#   'depart_time': '2023-10-31 10:16:00.000',
#   'track': '1',
#   'track_change': None,
#   'platform': 'B',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R5N',
#   'train_id': '9512',
#   'origin': 'Malvern',
#   'destination': 'Temple U',
#   'line': 'Paoli/Thorndale',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': 'Ardmore',
#   'sched_time': '2023-10-31 10:20:00.000',
#   'depart_time': '2023-10-31 10:21:00.000',
#   'track': '2',
#   'track_change': None,
#   'platform': 'B',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R8/3N',
#   'train_id': '8322',
#   'origin': 'Chestnut Hill West',
#   'destination': 'West Trenton',
#   'line': 'Chestnut Hill West',
#   'status': '1 min',
#   'service_type': 'LOCAL',
#   'next_station': 'Allen Lane',
#   'sched_time': '2023-10-31 10:27:00.000',
#   'depart_time': '2023-10-31 10:28:00.000',
#   'track': '2',
#   'track_change': None,
#   'platform': 'A',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R2/5N',
#   'train_id': '9208',
#   'origin': 'Newark',
#   'destination': 'Temple U',
#   'line': 'Wilmington/Newark',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': 'Crum Lynne',
#   'sched_time': '2023-10-31 10:28:00.000',
#   'depart_time': '2023-10-31 10:29:00.000',
#   'track': '1',
#   'track_change': None,
#   'platform': 'A',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R4/8N',
#   'train_id': '4822',
#   'origin': 'Airport Terminal E-F',
#   'destination': 'Fox Chase',
#   'line': 'Airport',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': None,
#   'sched_time': '2023-10-31 10:34:00.000',
#   'depart_time': '2023-10-31 10:35:00.000',
#   'track': '1',
#   'track_change': None,
#   'platform': 'B',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R5N',
#   'train_id': '9544',
#   'origin': 'Thorndale',
#   'destination': 'Temple U',
#   'line': 'Paoli/Thorndale',
#   'status': '12 min',
#   'service_type': 'LOCAL',
#   'next_station': 'Whitford',
#   'sched_time': '2023-10-31 10:46:00.000',
#   'depart_time': '2023-10-31 10:47:00.000',
#   'track': '1',
#   'track_change': None,
#   'platform': 'B',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R7N',
#   'train_id': '9708',
#   'origin': 'Trenton',
#   'destination': 'Temple U',
#   'line': 'Trenton',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': None,
#   'sched_time': '2023-10-31 10:51:00.000',
#   'depart_time': '2023-10-31 10:52:00.000',
#   'track': '2',
#   'track_change': None,
#   'platform': 'B',
#   'platform_change': None},
#  {'direction': 'N',
#   'path': 'R3/2N',
#   'train_id': '3214',
#   'origin': 'Wawa',
#   'destination': 'Norristown',
#   'line': 'Media/Wawa',
#   'status': 'On Time',
#   'service_type': 'LOCAL',
#   'next_station': None,
#   'sched_time': '2023-10-31 10:56:00.000',
#   'depart_time': '2023-10-31 10:57:00.000',
#   'track': '1',
#   'track_change': None,
#   'platform': 'A',
#   'platform_change': None}]

# %%
# code goes here

arrivals_response = requests.get("http://www3.septa.org/hackathon/Arrivals/Suburban Station/10")

arrivals_dict = arrivals_response.json()
arrivals_dict=list(arrivals_dict.values())[0][0]['Northbound']
trains=[]

# For each item in the arrivals dictionary key list, 
for train in arrivals_dict:
    trains_dict={'direction':train['direction'],
                   'line':train['line'],
                   'sched_time':train['sched_time'],
                   'status':train['status'],
                   'track':train['track']}
    trains.append(trains_dict)
pprint(trains_dict)
# Out:
# {'direction': 'N',
#  'line': 'Media/Wawa',
#  'sched_time': '2023-10-31 10:56:00.000',
#  'status': 'On Time',
#  'track': '1'}

# %% [markdown]
# #### 3.1.2.4 Open geo-location data
# Geolocation data can also be found in JSON format. The [OpenStreetMap (OSM) API](https://wiki.openstreetmap.org/wiki/Main_Page) can be used to request geographic data. Usually, map data is stored in the form of polygons, shapes with vertices consisting of latitude-longitude points. For example, we can obtain the polygon for Philadelphia from OSM like this:

# %%
response = requests.get("https://nominatim.openstreetmap.org/search.php?q=Philadelphia+Pennsylvania&polygon_geojson=1&format=json")

pprint(response.json())
# Out:
# [{'addresstype': 'city',
#   'boundingbox': ['39.8670050', '40.1379593', '-75.2802977', '-74.9558314'],
#   'class': 'boundary',
#   'display_name': 'Philadelphia, Pennsylvania, United States',
#   'geojson': {'coordinates': [[[-75.2802977, 39.9750019],
#                                [-75.2802246, 39.9748885],
#                                [-75.280192, 39.974835],
#                                [-75.28013, 39.974735],
#                                [-75.280085, 39.974624],
#                                [-75.280044, 39.97454],
#                                [-75.280027, 39.974502],
#                                [-75.279955, 39.974424],
#                                [-75.279805, 39.97432],
#                                [-75.2796, 39.974185],
#                                [-75.279465, 39.974122],
#                                [-75.279359, 39.974072],
#                                [-75.279242, 39.974031],
#                                [-75.27917, 39.973986],
#                                [-75.279123, 39.973913],
#                                [-75.279109, 39.973812],
#                                [-75.279081, 39.973691],
#                                [-75.279046, 39.973618],
#                                [-75.278998, 39.973526],
#                                [-75.278971, 39.973446],
#                                [-75.278952, 39.973359],
#                                [-75.278916, 39.973315],
#                                [-75.278859, 39.973247],
#                                [-75.27883, 39.973162],
#                                [-75.27881, 39.973051],
#                                [-75.278795, 39.97295],
#                                [-75.278784, 39.972841],
#                                [-75.27878, 39.972745],
#                                [-75.278777, 39.972692],
#                                [-75.278759, 39.972634],
#                                [-75.278724, 39.97253],
#                                [-75.278697, 39.972414],
#                                [-75.278657, 39.972332],
#                                [-75.278609, 39.972263],
#                                [-75.278537, 39.972185],
#                                [-75.278449, 39.972106],
#                                [-75.278352, 39.972013],
#                                [-75.278297, 39.971928],
#                                [-75.278018, 39.971751],
#                                [-75.277967, 39.971714],
#                                [-75.277886, 39.971693],
#                                [-75.277765, 39.971678],
#                                [-75.277676, 39.971659],
#                                [-75.277641, 39.971643],
#                                [-75.277591, 39.971615],
#                                [-75.277553, 39.971583],
#                                [-75.277529, 39.971555],
#                                [-75.277513, 39.971518],
#                                [-75.277505, 39.971487],
#                                [-75.277503, 39.971452],
#                                [-75.277509, 39.971424],
#                                [-75.277523, 39.971401],
#                                [-75.277551, 39.971386],
#                                [-75.277596, 39.971377],
#                                [-75.277646, 39.971362],
#                                [-75.277688, 39.971345],
#                                [-75.277713, 39.971321],
#                                [-75.277704, 39.971284],
#                                [-75.277687, 39.971247],
#                                [-75.277656, 39.971209],
#                                [-75.277611, 39.971175],
#                                [-75.277576, 39.97115],
#                                [-75.27754, 39.971127],
#                                [-75.277491, 39.97111],
#                                [-75.277421, 39.971097],
#                                [-75.277338, 39.971083],
#                                [-75.277266, 39.971082],
#                                [-75.277198, 39.971082],
#                                [-75.277136, 39.971089],
#                                [-75.277073, 39.971105],
#                                [-75.276896, 39.971175],
#                                [-75.276825, 39.971215],
#                                [-75.27676, 39.971244],
#                                [-75.276689, 39.971253],
#                                [-75.276583, 39.971262],
#                                [-75.276524, 39.971224],
#                                [-75.276485, 39.971178],
#                                [-75.276471, 39.971135],
#                                [-75.276528, 39.971095],
#                                [-75.276587, 39.971056],
#                                [-75.276636, 39.971016],
#                                [-75.276662, 39.970983],
#                                [-75.276674, 39.970945],
#                                [-75.276667, 39.970907],
#                                [-75.276656, 39.970862],
#                                [-75.27664, 39.970828],
#                                [-75.276611, 39.970776],
#                                [-75.276553, 39.970672],
#                                [-75.276508, 39.97059],
#                                [-75.276467, 39.97052],
#                                [-75.276438, 39.970468],
#                                [-75.276411, 39.970416],
#                                [-75.27637, 39.970388],
#                                [-75.276302, 39.970351],
#                                [-75.276277, 39.970342],
#                                [-75.276245, 39.97033],
#                                [-75.276186, 39.970324],
#                                [-75.276005, 39.970312],
#                                [-75.275819, 39.97031],
#                                [-75.275705, 39.970293],
#                                [-75.275652, 39.970259],
#                                [-75.275606, 39.970211],
#                                [-75.275567, 39.970125],
#                                [-75.275494, 39.969929],
#                                [-75.275456, 39.969778],
#                                [-75.275394, 39.969575],
#                                [-75.275362, 39.969503],
#                                [-75.27532, 39.969411],
#                                [-75.275266, 39.969364],
#                                [-75.275197, 39.969325],
#                                [-75.275084, 39.969297],
#                                [-75.275027, 39.969289],
#                                [-75.274889, 39.969287],
#                                [-75.274808, 39.969293],
#                                [-75.274488, 39.96931],
#                                [-75.274326, 39.969316],
#                                [-75.27415, 39.969317],
#                                [-75.274012, 39.969315],
#                                [-75.273912, 39.96931],
#                                [-75.27381, 39.969297],
#                                [-75.273681, 39.969287],
#                                [-75.273569, 39.969278],
#                                [-75.273492, 39.969276],
#                                [-75.273415, 39.969281],
#                                [-75.27328, 39.969294],
#                                [-75.273185, 39.969305],
#                                [-75.273054, 39.969305],
#                                [-75.272957, 39.969293],
#                                [-75.272815, 39.969244],
#                                [-75.272726, 39.969217],
#                                [-75.272625, 39.969178],
#                                [-75.272505, 39.969131],
#                                [-75.272344, 39.969094],
#                                [-75.272196, 39.969047],
#                                [-75.272086, 39.969011],
#                                [-75.272024, 39.968985],
#                                [-75.271985, 39.968944],
#                                [-75.271922, 39.968859],
#                                [-75.271863, 39.968805],
#                                [-75.271802, 39.968756],
#                                [-75.271698, 39.968729],
#                                [-75.27159, 39.968715],
#                                [-75.271491, 39.968709],
#                                [-75.271407, 39.968704],
#                                [-75.271327, 39.968691],
#                                [-75.271241, 39.968663],
#                                [-75.271168, 39.968633],
#                                [-75.271109, 39.968619],
#                                [-75.271043, 39.968609],
#                                [-75.270986, 39.968603],
#                                [-75.270913, 39.968619],
#                                [-75.270838, 39.968644],
#                                [-75.270773, 39.968663],
#                                [-75.270718, 39.968671],
#                                [-75.270651, 39.968675],
#                                [-75.270598, 39.96866],
#                                [-75.27057, 39.968638],
#                                [-75.270522, 39.968602],
#                                [-75.270501, 39.968585],
#                                [-75.270447, 39.968528],
#                                [-75.270422, 39.968479],
#                                [-75.270413, 39.968428],
#                                [-75.270402, 39.968357],
#                                [-75.270388, 39.968322],
#                                [-75.270297, 39.968184],
#                                [-75.270192, 39.967977],
#                                [-75.27014, 39.967872],
#                                [-75.270073, 39.967729],
#                                [-75.270054, 39.967653],
#                                [-75.27003, 39.967552],
#                                [-75.270002, 39.967479],
#                                [-75.269961, 39.967425],
#                                [-75.269919, 39.96738],
#                                [-75.269857, 39.967344],
#                                [-75.269801, 39.967326],
#                                [-75.269741, 39.967315],
#                                [-75.26967, 39.967317],
#                                [-75.269614, 39.967331],
#                                [-75.269548, 39.967355],
#                                [-75.269498, 39.967375],
#                                [-75.269445, 39.967388],
#                                [-75.269357, 39.967402],
#                                [-75.269272, 39.967391],
#                                [-75.269206, 39.967381],
#                                [-75.269157, 39.967374],
#                                [-75.269125, 39.967361],
#                                [-75.26908, 39.96733],
#                                [-75.269044, 39.967285],
#                                [-75.269016, 39.967235],
#                                [-75.268916, 39.967041],
#                                [-75.268846, 39.966946],
#                                [-75.268773, 39.96686],
#                                [-75.268701, 39.966796],
#                                [-75.268568, 39.966691],
#                                [-75.268513, 39.966651],
#                                [-75.268461, 39.966618],
#                                [-75.268393, 39.966589],
#                                [-75.268129, 39.966491],
#                                [-75.267909, 39.9664],
#                                [-75.267818, 39.966359],
#                                [-75.267779, 39.966341],
#                                [-75.26767, 39.966298],
#                                [-75.267598, 39.966273],
#                                [-75.267538, 39.966272],
#                                [-75.26753, 39.96627],
#                                [-75.267475, 39.96626],
#                                [-75.267386, 39.966215],
#                                [-75.267245, 39.966117],
#                                [-75.267214, 39.966092],
#                                [-75.267138, 39.966062],
#                                [-75.2671, 39.96605],
#                                [-75.267024, 39.966025],
#                                [-75.266909, 39.966008],
#                                [-75.266795, 39.966009],
#                                [-75.266707, 39.966021],
#                                [-75.266545, 39.966021],
#                                [-75.266395, 39.966018],
#                                [-75.266313, 39.966004],
#                                [-75.266193, 39.965968],
#                                [-75.266062, 39.96593],
#                                [-75.266048, 39.965926],
#                                [-75.265921, 39.96586],
#                                [-75.265858, 39.965791],
#                                [-75.265806, 39.965716],
#                                [-75.265744, 39.965626],
#                                [-75.265656, 39.965526],
#                                [-75.265598, 39.965448],
#                                [-75.265566, 39.965404],
#                                [-75.265528, 39.96535],
#                                [-75.265448, 39.965257],
#                                [-75.265388, 39.965224],
#                                [-75.265252, 39.965207],
#                                [-75.265058, 39.965192],
#                                [-75.264918, 39.965189],
#                                [-75.264758, 39.965184],
#                                [-75.264644, 39.965179],
#                                [-75.264553, 39.965181],
#                                [-75.264496, 39.965195],
#                                [-75.264373, 39.965242],
#                                [-75.264242, 39.965312],
#                                [-75.264131, 39.965373],
#                                [-75.264056, 39.965421],
#                                [-75.264016, 39.965457],
#                                [-75.26399, 39.965491],
#                                [-75.263928, 39.965529],
#                                [-75.263855, 39.965556],
#                                [-75.26377, 39.965596],
#                                [-75.263696, 39.965614],
#                                [-75.263614, 39.965621],
#                                [-75.26353, 39.965605],
#                                [-75.263467, 39.965577],
#                                [-75.263383, 39.965545],
#                                [-75.263307, 39.965505],
#                                [-75.263251, 39.965474],
#                                [-75.263195, 39.965457],
#                                [-75.263144, 39.965459],
#                                [-75.263092, 39.965486],
#                                [-75.263028, 39.965531],
#                                [-75.262961, 39.965579],
#                                [-75.262919, 39.965609],
#                                [-75.262836, 39.965639],
#                                [-75.262766, 39.965647],
#                                [-75.262679, 39.965638],
#                                [-75.262618, 39.965626],
#                                [-75.262559, 39.965617],
#                                [-75.262512, 39.965611],
#                                [-75.262457, 39.965633],
#                                [-75.262422, 39.965676],
#                                [-75.262382, 39.965739],
#                                [-75.262342, 39.965784],
#                                [-75.262273, 39.965851],
#                                [-75.262265, 39.965858],
#                                [-75.262242, 39.96588],
#                                [-75.2620986, 39.9660512],
#                                [-75.262038, 39.9661255],
#                                [-75.2619587, 39.9661715],
#                                [-75.261828, 39.9661931],
#                                [-75.2617419, 39.9662059],
#                                [-75.2616575, 39.966183],
#                                [-75.2615544, 39.9661318],
#                                [-75.2614663, 39.9660786],
#                                [-75.2614034, 39.9660264],
#                                [-75.2613196, 39.9660097],
#                                [-75.2612418, 39.966017],
#                                [-75.2611707, 39.9660573],
#                                [-75.2611076, 39.9661432],
#                                [-75.2610488, 39.9661862],
#                                [-75.260932, 39.966242],
#                                [-75.260828, 39.96627],
#                                [-75.260751, 39.96628],
#                                [-75.260662, 39.966269],
#                                [-75.260584, 39.966273],
#                                [-75.2604549, 39.9662706],
#                                [-75.260309, 39.966257],
#                                [-75.260065, 39.966196],
#                                [-75.259909, 39.966115],
#                                [-75.259779, 39.966081],
#                                [-75.259649, 39.966041],
#                                [-75.259551, 39.96601],
#                                [-75.25945, 39.965947],
#                                [-75.259428, 39.965892],
#                                [-75.259427, 39.965813],
#                                [-75.259423, 39.965761],
#                                [-75.2594, 39.965716],
#                                [-75.259333, 39.965698],
#                                [-75.259214, 39.965697],
#                                [-75.259078, 39.965692],
#                                [-75.258974, 39.965676],
#                                [-75.25889, 39.965648],
#                                [-75.258839, 39.965614],
#                                [-75.258797, 39.965571],
#                                [-75.258767, 39.965516],
#                                [-75.258738, 39.965447],
#                                [-75.258709, 39.965378],
#                                [-75.2587, 39.965324],
#                                [-75.258711, 39.96524],
#                                [-75.258715, 39.965059],
#                                [-75.258713, 39.964965],
#                                [-75.258706, 39.964903],
#                                [-75.258684, 39.964846],
#                                [-75.258637, 39.964766],
#                                [-75.25859, 39.964708],
#                                [-75.258547, 39.964618],
#                                [-75.25851, 39.964535],
#                                [-75.25847, 39.964484],
#                                [-75.258407, 39.964452],
#                                [-75.258339, 39.964449],
#                                [-75.258271, 39.964452],
#                                [-75.258189, 39.96445],
#                                [-75.25812, 39.964446],
#                                [-75.258058, 39.964428],
#                                [-75.258007, 39.964399],
#                                [-75.257976, 39.964377],
#                                [-75.257944, 39.964301],
#                                [-75.257944, 39.964236],
#                                [-75.257962, 39.964161],
#                                [-75.257991, 39.964095],
#                                [-75.258014, 39.963993],
#                                [-75.258012, 39.963854],
#                                [-75.258014, 39.963739],
#                                [-75.257994, 39.963677],
#                                [-75.257933, 39.963624],
#                                [-75.257858, 39.963594],
#                                [-75.257788, 39.963602],
#                                [-75.257705, 39.963631],
#                                [-75.257629, 39.963664],
#                                [-75.257543, 39.963705],
#                                [-75.257487, 39.963744],
#                                [-75.257418, 39.963766],
#                                [-75.2573049, 39.9637752],
#                                [-75.2572326, 39.9637761],
#                                [-75.2571266, 39.9637643],
#                                [-75.256981, 39.963688],
#                                [-75.2569, 39.963672],
#                                [-75.256816, 39.963677],
#                                [-75.256746, 39.963688],
#                                [-75.256686, 39.963719],
#                                [-75.256586, 39.963802],
#                                [-75.256383, 39.963974],
#                                [-75.256281, 39.964079],
#                                [-75.256193, 39.964155],
#                                [-75.256083, 39.964242],
#                                [-75.255966, 39.964312],
#                                [-75.255892, 39.964372],
#                                [-75.255852, 39.964437],
#                                [-75.255812, 39.964471],
#                                [-75.255686, 39.964546],
#                                [-75.255543, 39.964595],
#                                [-75.255409, 39.96463],
#                                [-75.255267, 39.964655],
#                                [-75.255112, 39.964691],
#                                [-75.254937, 39.964763],
#                                [-75.254738, 39.96485],
#                                [-75.254632, 39.964925],
#                                [-75.254543, 39.964992],
#                                [-75.254456, 39.965046],
#                                [-75.254381, 39.965127],
#                                [-75.254337, 39.965211],
#                                [-75.254302, 39.965273],
#                                [-75.254223, 39.965337],
#                                [-75.25414, 39.965404],
#                                [-75.254046, 39.965402],
#                                [-75.253936, 39.96539],
#                                [-75.253712, 39.965329],
#                                [-75.253582, 39.9653],
#                                [-75.253407, 39.965261],
#                                [-75.253314, 39.965226],
#                                [-75.2532156, 39.9651949],
#                                [-75.253077, 39.965214],
#                                [-75.252972, 39.965235],
#                                [-75.252843, 39.965244],
#                                [-75.252636, 39.965251],
#                                [-75.252334, 39.96528],
#                                [-75.252094, 39.965305],
#                                [-75.251923, 39.965318],
#                                [-75.251811, 39.96533],
#                                [-75.251707, 39.965346],
#                                [-75.251603, 39.965356],
#                                [-75.251496, 39.965337],
#                                [-75.251427, 39.965302],
#                                [-75.251368, 39.965249],
#                                [-75.251353, 39.965219],
#                                [-75.251341, 39.965192],
#                                [-75.251336, 39.965138],
#                                [-75.251342, 39.965072],
#                                [-75.251283, 39.965003],
#                                [-75.251201, 39.964912],
#                                [-75.2511683, 39.9648942],
#                                [-75.251102, 39.964858],
#                                [-75.2510368, 39.9648333],
#                                [-75.250913, 39.964837],
#                                [-75.250757, 39.964879],
#                                [-75.250606, 39.964948],
#                                [-75.2504297, 39.9650246],
#                                [-75.250313, 39.965069],
#                                [-75.250221, 39.965076],
#                                [-75.250133, 39.965067],
#                                [-75.2500501, 39.9650395],
#                                [-75.24999, 39.965001],
#                                [-75.249912, 39.964947],
#                                [-75.249848, 39.964908],
#                                [-75.2497449, 39.9648582],
#                                [-75.249465, 39.964721],
#                                [-75.248967, 39.964494],
#                                [-75.248615, 39.964352],
#                                [-75.248056, 39.964074],
#                                [-75.247903, 39.963979],
#                                [-75.247778, 39.963876],
#                                [-75.247685, 39.963777],
#                                [-75.247564, 39.963638],
#                                [-75.247479, 39.963528],
#                                [-75.247434, 39.963417],
#                                [-75.247405, 39.963327],
#                                [-75.247399, 39.963249],
#                                [-75.247418, 39.963191],
#                                [-75.247489, 39.963119],
#                                [-75.247604, 39.962992],
#                                [-75.247642, 39.96295],
#                                [-75.247653, 39.9628242],
#                                [-75.2476642, 39.9627501],
#                                [-75.247681, 39.96268],
#                                [-75.2477355, 39.9625573],
#                                [-75.2477733, 39.9622794],
#                                [-75.2476982, 39.9621627],
#                                [-75.2477053, 39.9620216],
#                                [-75.2477218, 39.9618771],
#                                [-75.2478163, 39.9616797],
#                                [-75.2478248, 39.9615021],
#                                [-75.2478248, 39.9613442],
#                                [-75.2478592, 39.9612126],
#                                [-75.2478935, 39.9610745],
#                                [-75.2479708, 39.9609429],
#                                [-75.2481252, 39.9607982],
#                                [-75.2482282, 39.9606469],
#                                [-75.2482969, 39.9605416],
#                                [-75.2483398, 39.9604298],
#                                [-75.2485115, 39.9602784],
#                                [-75.2486316, 39.9602061],
#                                [-75.2488033, 39.9601074],
#                                [-75.2490351, 39.959989],
#                                [-75.2491724, 39.9598903],
#                                [-75.2493011, 39.9597916],
#                                [-75.2494299, 39.9597061],
#                                [-75.249593, 39.9596271],
#                                [-75.2498504, 39.9595679],
#                                [-75.2500307, 39.959489],
#                                [-75.2501337, 39.9594429],
#                                [-75.2502796, 39.9593837],
#                                [-75.2504856, 39.9593048],
#                                [-75.2506058, 39.9592258],
#                                [-75.2507517, 39.9591337],
#                                [-75.2508461, 39.9590679],
#                                [-75.250889, 39.9589692],
#                                [-75.2508976, 39.9588442],
#                                [-75.2508976, 39.9586864],
#                                [-75.2508461, 39.9585482],
#                                [-75.250786, 39.9584561],
#                                [-75.2507002, 39.9583377],
#                                [-75.2505886, 39.9582456],
#                                [-75.2505285, 39.9581798],
#                                [-75.2504427, 39.9580745],
#                                [-75.2503568, 39.9579363],
#                                [-75.2502281, 39.9578113],
#                                [-75.250168, 39.9577127],
#                                [-75.2501165, 39.9576469],
#                                [-75.2499964, 39.9575811],
#                                [-75.2498934, 39.9575153],
#                                [-75.2497474, 39.9574298],
#                                [-75.2495844, 39.9573705],
#                                [-75.249344, 39.9571403],
#                                [-75.2492325, 39.9570547],
#                                [-75.2491295, 39.9570218],
#                                [-75.2490007, 39.9569758],
#                                [-75.2489149, 39.9568968],
#                                [-75.2489149, 39.9568179],
#                                [-75.2488977, 39.9567258],
#                                [-75.2488977, 39.9566139],
#                                [-75.2489063, 39.9565153],
#                                [-75.2489664, 39.9564297],
#                                [-75.2490866, 39.9563574],
#                                [-75.2492067, 39.9562192],
#                                [-75.2492325, 39.9561337],
#                                [-75.2492754, 39.956035],
#                                [-75.249241, 39.9559165],
#                                [-75.2492214, 39.9558213],
#                                [-75.2492005, 39.9557385],
#                                [-75.2492083, 39.9555816],
#                                [-75.2492558, 39.9554855],
#                                [-75.249346, 39.955385],
#                                [-75.249449, 39.9552848],
#                                [-75.2495153, 39.9552092],
#                                [-75.2495804, 39.9551463],
#                                [-75.2496187, 39.9550941],
#                                [-75.2496359, 39.9550415],
#                                [-75.2496702, 39.954956],
#                                [-75.2497045, 39.9548441],
#                                [-75.2497277, 39.9547227],
#                                [-75.249771, 39.9546087],
#                                [-75.2498196, 39.954507],
#                                [-75.2498762, 39.9543901],
#                                [-75.2499964, 39.9542849],
#                                [-75.250065, 39.954173],
#                                [-75.2501594, 39.9540612],
#                                [-75.2502538, 39.9539691],
#                                [-75.2503483, 39.9538769],
#                                [-75.250477, 39.9537651],
#                                [-75.2506573, 39.9536072],
#                                [-75.2507603, 39.9535019],
#                                [-75.2508632, 39.9533703],
#                                [-75.2509748, 39.9532519],
#                                [-75.251095, 39.9531203],
#                                [-75.2511207, 39.9530019],
#                                [-75.251095, 39.9528703],
#                                [-75.2510864, 39.9527782],
#                                [-75.2511207, 39.9526795],
#                                [-75.2512152, 39.9526137],
#                                [-75.251301, 39.9525413],
#                                [-75.251404, 39.9523571],
#                                [-75.2514726, 39.9522321],
#                                [-75.2515585, 39.9521202],
#                                [-75.2515928, 39.9520018],
#                                [-75.2516558, 39.9518008],
#                                [-75.2516404, 39.9516675],
#                                [-75.2516168, 39.9514882],
#                                [-75.2515701, 39.9513384],
#                                [-75.2515387, 39.9512581],
#                                [-75.2515089, 39.951209],
#                                [-75.2514471, 39.951159],
#                                [-75.2513696, 39.9511069],
#                                [-75.2513182, 39.951028],
#                                [-75.2512323, 39.950949],
#                                [-75.2511551, 39.950824],
#                                [-75.2511036, 39.9507253],
#                                [-75.251095, 39.9506332],
#                                [-75.2511086, 39.9505914],
#                                [-75.2511207, 39.9505542],
#                                [-75.2511551, 39.9504292],
#                                [-75.2511894, 39.9503042],
#                                [-75.2512237, 39.9502252],
#                                [-75.2512838, 39.95012],
#                                [-75.2513611, 39.9499752],
#                                [-75.2514126, 39.9498831],
#                                [-75.2514726, 39.9497976],
#                                [-75.251507, 39.949712],
#                                [-75.2515327, 39.9496133],
#                                [-75.2515842, 39.949508],
#                                [-75.2515928, 39.9494093],
#                                [-75.2515413, 39.9492778],
#                                [-75.2514898, 39.9491791],
#                                [-75.2513954, 39.9490475],
#                                [-75.2513182, 39.9489619],
#                                [-75.2512323, 39.9488369],
#                                [-75.2511808, 39.9487579],
#                                [-75.2510692, 39.948679],
#                                [-75.2509662, 39.9485737],
#                                [-75.2508375, 39.9484684],
#                                [-75.2507251, 39.9483687],
#                                [-75.2505628, 39.9483171],
#                                [-75.2504169, 39.9482052],
#                                [-75.2503654, 39.9480934],
#                                [-75.2503225, 39.9479091],
#                                [-75.2502882, 39.9477709],
#                                [-75.2502453, 39.9476328],
#                                [-75.2502538, 39.9475143],
#                                [-75.2502453, 39.9474288],
#                                [-75.2501938, 39.9473367],
#                                [-75.2501165, 39.947238],
#                                [-75.2500736, 39.9471129],
#                                [-75.2500393, 39.9469616],
#                                [-75.2499964, 39.9467181],
#                                [-75.2499191, 39.9466523],
#                                [-75.2498075, 39.9465799],
#                                [-75.2496187, 39.946501],
#                                [-75.24949, 39.9464023],
#                                [-75.2493526, 39.9463167],
#                                [-75.2492239, 39.9461983],
#                                [-75.2489321, 39.9459482],
#                                [-75.248769, 39.9457772],
#                                [-75.2486316, 39.945685],
#                                [-75.24846, 39.9455271],
#                                [-75.2483227, 39.9454481],
#                                [-75.2482969, 39.9453363],
#                                [-75.2482712, 39.9452178],
#                                [-75.2482025, 39.9451191],
#                                [-75.2481167, 39.9450007],
#                                [-75.248048, 39.9449151],
#                                [-75.2479364, 39.9448428],
#                                [-75.2477991, 39.9447375],
#                                [-75.2477047, 39.9446453],
#                                [-75.2476446, 39.9445598],
#                                [-75.2475711, 39.944515],
#                                [-75.2475022, 39.944448],
#                                [-75.2474492, 39.9444031],
#                                [-75.2474236, 39.9443551],
#                                [-75.2474107, 39.9443196],
#                                [-75.2474022, 39.9442469],
#                                [-75.247377, 39.944138],
#                                [-75.2473365, 39.9440586],
#                                [-75.2472755, 39.9439873],
#                                [-75.2472201, 39.9438996],
#                                [-75.2471856, 39.9438238],
#                                [-75.2471073, 39.9435924],
#                                [-75.2470781, 39.9435004],
#                                [-75.247034, 39.9434178],
#                                [-75.2469236, 39.9432766],
#                                [-75.2469236, 39.9431713],
#                                [-75.246915, 39.9430858],
#                                [-75.2468378, 39.9429871],
#                                [-75.2467863, 39.942895],
#                                [-75.246709, 39.9428292],
#                                [-75.2465631, 39.9427436],
#                                [-75.2464516, 39.9427041],
#                                [-75.2463571, 39.9426581],
#                                [-75.246134, 39.9426186],
#                                [-75.2459194, 39.942612],
#                                [-75.2457477, 39.9426252],
#                                [-75.2454902, 39.9426186],
#                                [-75.2451727, 39.9426054],
#                                [-75.2448723, 39.9426054],
#                                [-75.2447006, 39.9425923],
#                                [-75.2445461, 39.9425791],
#                                [-75.2444088, 39.9425659],
#                                [-75.2441942, 39.9425396],
#                                [-75.2439968, 39.9425199],
#                                [-75.2437736, 39.9424935],
#                                [-75.2435934, 39.9424606],
#                                [-75.243499, 39.9424212],
#                                [-75.2433273, 39.9423356],
#                                [-75.2431814, 39.942329],
#                                [-75.242984, 39.9423225],
#                                [-75.2427866, 39.9423159],
#                                [-75.2426063, 39.9423027],
#                                [-75.2424175, 39.9422961],
#                                [-75.2421686, 39.942283],
#                                [-75.2419626, 39.9422698],
#                                [-75.2416536, 39.9422566],
#                                [-75.2414648, 39.9422698],
#                                [-75.241233, 39.9422632],
#                                [-75.2410528, 39.9422632],
#                                [-75.2409069, 39.9422435],
#                                [-75.2407352, 39.9422237],
#                                [-75.2404692, 39.9422172],
#                                [-75.240349, 39.9421908],
#                                [-75.240246, 39.9421579],
#                                [-75.2401001, 39.9420395],
#                                [-75.24004, 39.9419408],
#                                [-75.2399713, 39.9418421],
#                                [-75.2399198, 39.9417434],
#                                [-75.2398855, 39.9416841],
#                                [-75.2397911, 39.9415788],
#                                [-75.239731, 39.9415065],
#                                [-75.2396795, 39.9414341],
#                                [-75.2396108, 39.9413419],
#                                [-75.2395508, 39.941263],
#                                [-75.239525, 39.941184],
#                                [-75.2394563, 39.9410721],
#                                [-75.2394134, 39.9409866],
#                                [-75.2394049, 39.9409274],
#                                [-75.2393877, 39.9408221],
#                                [-75.2393877, 39.9407234],
#                                [-75.2394306, 39.9406181],
#                                [-75.2394478, 39.9405194],
#                                [-75.2395508, 39.9404009],
#                                [-75.2396709, 39.9402759],
#                                [-75.2397997, 39.9401772],
#                                [-75.2399542, 39.9399797],
#                                [-75.2399971, 39.9398415],
#                                [-75.2400829, 39.9397362],
#                                [-75.2401687, 39.9396507],
#                                [-75.240246, 39.939552],
#                                [-75.2404091, 39.9394204],
#                                [-75.2405378, 39.9392953],
#                                [-75.2406065, 39.9392295],
#                                [-75.2406923, 39.9391374],
#                                [-75.2407352, 39.939065],
#                                [-75.2407781, 39.9389663],
#                                [-75.240761, 39.9388544],
#                                [-75.2407524, 39.9387689],
#                                [-75.2406923, 39.9386899],
#                                [-75.2406322, 39.9386175],
#                                [-75.2405206, 39.9385583],
#                                [-75.2404005, 39.9384464],
#                                [-75.2402975, 39.9383674],
#                                [-75.2401945, 39.938295],
#                                [-75.2400915, 39.9382555],
#                                [-75.2399713, 39.9381897],
#                                [-75.239834, 39.9381766],
#                                [-75.2395937, 39.9381568],
#                                [-75.2393705, 39.9381634],
#                                [-75.2392332, 39.9381502],
#                                [-75.2390873, 39.9381437],
#                                [-75.2390082, 39.9381437],
#                                [-75.2389328, 39.9381437],
#                                [-75.2386383, 39.9381693],
#                                [-75.2384779, 39.9381832],
#                                [-75.2382805, 39.9382029],
#                                [-75.2382101, 39.9382059],
#                                [-75.238126, 39.9382095],
#                                [-75.2378427, 39.9382358],
#                                [-75.2377226, 39.9382621],
#                                [-75.2375423, 39.938295],
#                                [-75.2373363, 39.9383345],
#                                [-75.2371561, 39.9383608],
#                                [-75.2369501, 39.9384135],
#                                [-75.236684, 39.9384398],
#                                [-75.2365209, 39.938453],
#                                [-75.2362892, 39.9384464],
#                                [-75.2361624, 39.9384438],
#                                [-75.2359716, 39.9384398],
#                                [-75.2358587, 39.9384238],
#                                [-75.2357399, 39.9384069],
#                                [-75.2356369, 39.9383806],
#                                [-75.2354795, 39.9383367],
#                                [-75.2354481, 39.9383279],
#                                [-75.2353107, 39.9383148],
#                                [-75.2352666, 39.9382979],
#                                [-75.2351734, 39.9382621],
#                                [-75.235079, 39.9382095],
#                                [-75.2350189, 39.9380976],
#                                [-75.2349932, 39.9379923],
#                                [-75.2349991, 39.937928],
#                                [-75.2350017, 39.9379002],
#                                [-75.2350017, 39.937808],
#                                [-75.2350073, 39.9377485],
#                                [-75.2350103, 39.9377159],
#                                [-75.2349932, 39.9376369],
#                                [-75.2349502, 39.9375382],
#                                [-75.2349219, 39.9375084],
#                                [-75.2348816, 39.9374658],
#                                [-75.2348472, 39.9373803],
#                                [-75.2348301, 39.9373145],
#                                [-75.2348215, 39.9372026],
#                                [-75.2348423, 39.9370481],
#                                [-75.2348472, 39.9370117],
#                                [-75.2348644, 39.9369262],
#                                [-75.2348387, 39.9368077],
#                                [-75.2348605, 39.9367508],
#                                [-75.2348816, 39.9366958],
#                                [-75.2349417, 39.9365511],
#                                [-75.2350017, 39.9364326],
#                                [-75.2350147, 39.9363831],
#                                [-75.2350275, 39.9363339],
#                                [-75.2350532, 39.9362417],
#                                [-75.2351133, 39.936143],
#                                [-75.2351496, 39.9360914],
#                                [-75.2351734, 39.9360575],
#                                [-75.2352936, 39.9359785],
#                                [-75.235388, 39.9359258],
#                                [-75.2354996, 39.93586],
#                                [-75.2356111, 39.935814],
#                                [-75.2356798, 39.9357679],
#                                [-75.2357914, 39.9356889],
#                                [-75.2359201, 39.9356165],
#                                [-75.2360489, 39.9355507],
#                                [-75.2361175, 39.9354652],
#                                [-75.2362034, 39.9353993],
#                                [-75.2362806, 39.935327],
#                                [-75.2363579, 39.935248],
#                                [-75.2364094, 39.9351756],
#                                [-75.2364523, 39.9351098],
#                                [-75.2364952, 39.9350111],
#                                [-75.2365038, 39.9349189],
#                                [-75.2365124, 39.934807],
#                                [-75.2365381, 39.9347215],
#                                [-75.2365381, 39.9346228],
#                                [-75.2365639, 39.9345635],
#                                [-75.2365724, 39.9344714],
#                                [-75.2365896, 39.9343595],
#                                [-75.2366154, 39.9342739],
#                                [-75.2366154, 39.9341884],
#                                [-75.2366669, 39.9340897],
#                                [-75.2365553, 39.9337803],
#                                [-75.2366325, 39.9336092],
#                                [-75.2366754, 39.9334908],
#                                [-75.2367441, 39.933392],
#                                [-75.2368042, 39.9332867],
#                                [-75.23689, 39.9331617],
#                                [-75.2369501, 39.933063],
#                                [-75.2369844, 39.9329774],
#                                [-75.2370359, 39.9328919],
#                                [-75.2371389, 39.93278],
#                                [-75.2372248, 39.9327207],
#                                [-75.2373106, 39.9326483],
#                                [-75.2374307, 39.9325759],
#                                [-75.2375681, 39.9325365],
#                                [-75.2377569, 39.9325299],
#                                [-75.2378599, 39.9325299],
#                                [-75.2380316, 39.9325694],
#                                [-75.2383234, 39.9326154],
#                                [-75.2384521, 39.9326549],
#                                [-75.238598, 39.9327076],
#                                [-75.2386753, 39.9327471],
#                                [-75.2388126, 39.9328063],
#                                [-75.2389671, 39.932905],
#                                [-75.2390959, 39.9329972],
#                                [-75.2391903, 39.9330696],
#                                [-75.2393362, 39.9331617],
#                                [-75.2394821, 39.9332078],
#                                [-75.2396366, 39.9332802],
#                                [-75.2397911, 39.9333328],
#                                [-75.2399113, 39.9333723],
#                                [-75.2400142, 39.9334118],
#                                [-75.240349, 39.9335961],
#                                [-75.2405121, 39.9336421],
#                                [-75.240658, 39.9336553],
#                                [-75.2409756, 39.933629],
#                                [-75.2411987, 39.9336092],
#                                [-75.2414047, 39.9335961],
#                                [-75.2415678, 39.9335566],
#                                [-75.2417051, 39.9335105],
#                                [-75.2419626, 39.9334513],
#                                [-75.2420914, 39.933392],
#                                [-75.2421686, 39.9333196],
#                                [-75.2422544, 39.9331946],
#                                [-75.2423403, 39.9330893],
#                                [-75.2423918, 39.9330037],
#                                [-75.2424604, 39.9328787],
#                                [-75.2425205, 39.9327997],
#                                [-75.2426321, 39.9326878],
#                                [-75.2427608, 39.932543],
#                                [-75.2427952, 39.9324641],
# ...
#                                [-75.230949, 40.027416],
#                                [-75.230745, 40.027312],
#                                [-75.229678, 40.026793],
#                                [-75.228249, 40.026082],
#                                [-75.228216, 40.026066],
#                                [-75.228178, 40.026046],
#                                [-75.2281076, 40.0260097],
#                                [-75.228006, 40.025961],
#                                [-75.227952, 40.025934],
#                                [-75.226652, 40.025267],
#                                [-75.226513, 40.025197],
#                                [-75.226308, 40.025092],
#                                [-75.225191, 40.024459],
#                                [-75.223945, 40.023809],
#                                [-75.22367, 40.023633],
#                                [-75.223037, 40.023196],
#                                [-75.222205, 40.022542],
#                                [-75.221216, 40.022187],
#                                [-75.220498, 40.022026],
#                                [-75.219693, 40.02175],
#                                [-75.219583, 40.021713],
#                                [-75.219481, 40.021696],
#                                [-75.219331, 40.021671],
#                                [-75.2192388, 40.0216263],
#                                [-75.218558, 40.021296],
#                                [-75.218488, 40.021258],
#                                [-75.217344, 40.020423],
#                                [-75.216255, 40.019507],
#                                [-75.21567, 40.018886],
#                                [-75.215424, 40.018626],
#                                [-75.214663, 40.017835],
#                                [-75.214644, 40.017815],
#                                [-75.213855, 40.016914],
#                                [-75.213462, 40.016561],
#                                [-75.213386, 40.016473],
#                                [-75.213135, 40.016182],
#                                [-75.208722, 40.013349],
#                                [-75.208008, 40.012997],
#                                [-75.207728, 40.012805],
#                                [-75.207628, 40.012736],
#                                [-75.207599, 40.012719],
#                                [-75.206405, 40.012002],
#                                [-75.2057752, 40.0116551],
#                                [-75.2070544, 40.0106108],
#                                [-75.2098348, 40.0090677],
#                                [-75.2107421, 40.0085968],
#                                [-75.213273, 40.0073911],
#                                [-75.2137763, 40.0071659],
#                                [-75.215055, 40.0066035],
#                                [-75.2183557, 40.0050448],
#                                [-75.2184808, 40.004986],
#                                [-75.2187252, 40.0048713],
#                                [-75.2188738, 40.0048015],
#                                [-75.2192383, 40.0046304],
#                                [-75.2197201, 40.0044041],
#                                [-75.2198205, 40.004357],
#                                [-75.2205706, 40.0040045],
#                                [-75.2206928, 40.0039471],
#                                [-75.2208579, 40.0038695],
#                                [-75.2209935, 40.0038057],
#                                [-75.2211935, 40.0037117],
#                                [-75.2213446, 40.0036407],
#                                [-75.2215868, 40.0035269],
#                                [-75.2221329, 40.0032702],
#                                [-75.22278, 40.002966],
#                                [-75.2230659, 40.0028316],
#                                [-75.2231392, 40.0027972],
#                                [-75.2232458, 40.002747],
#                                [-75.2235553, 40.0026016],
#                                [-75.2236334, 40.0025649],
#                                [-75.2237665, 40.0025026],
#                                [-75.224164, 40.0023167],
#                                [-75.224444, 40.0021858],
#                                [-75.2246736, 40.0020785],
#                                [-75.2256121, 40.0016395],
#                                [-75.2258835, 40.0015126],
#                                [-75.2260886, 40.0014193],
#                                [-75.2263109, 40.0013192],
#                                [-75.2264267, 40.001267],
#                                [-75.2283762, 40.0003293],
#                                [-75.2286667, 40.0001913],
#                                [-75.2287422, 40.0001555],
#                                [-75.2288061, 40.0001255],
#                                [-75.2288307, 40.000114],
#                                [-75.2291266, 39.9999753],
#                                [-75.229297, 39.9998954],
#                                [-75.2294612, 39.9998185],
#                                [-75.2294957, 39.9998024],
#                                [-75.2295759, 39.9997648],
#                                [-75.2296317, 39.9997386],
#                                [-75.2298399, 39.999641],
#                                [-75.2299342, 39.9995968],
#                                [-75.229986, 39.9995725],
#                                [-75.2301922, 39.9994759],
#                                [-75.2302196, 39.999463],
#                                [-75.2302316, 39.9994574],
#                                [-75.2303044, 39.9994233],
#                                [-75.230393, 39.9993818],
#                                [-75.2304271, 39.9993658],
#                                [-75.2304389, 39.9993603],
#                                [-75.2305034, 39.9993301],
#                                [-75.2307089, 39.9992337],
#                                [-75.2307907, 39.9991954],
#                                [-75.2308937, 39.9991471],
#                                [-75.2310073, 39.9990939],
#                                [-75.2312946, 39.9989593],
#                                [-75.2313551, 39.9989309],
#                                [-75.2317034, 39.9987676],
#                                [-75.2319529, 39.9986507],
#                                [-75.2320814, 39.9985905],
#                                [-75.2321604, 39.9985534],
#                                [-75.2323082, 39.9984841],
#                                [-75.2323395, 39.9984695],
#                                [-75.23245, 39.9984177],
#                                [-75.2325374, 39.9983767],
#                                [-75.2325646, 39.998364],
#                                [-75.2326692, 39.998315],
#                                [-75.2330761, 39.9981243],
#                                [-75.2332301, 39.9980511],
#                                [-75.2335725, 39.9978925],
#                                [-75.2336314, 39.9978641],
#                                [-75.2338216, 39.9977749],
#                                [-75.2341826, 39.9976057],
#                                [-75.2343069, 39.9975474],
#                                [-75.2345954, 39.9974122],
#                                [-75.2351873, 39.9971348],
#                                [-75.2352829, 39.99709],
#                                [-75.2354318, 39.9970203],
#                                [-75.2359613, 39.996772],
#                                [-75.2361909, 39.9966642],
#                                [-75.2364033, 39.9965646],
#                                [-75.2365922, 39.996476],
#                                [-75.2371629, 39.9962081],
#                                [-75.2373554, 39.9961178],
#                                [-75.2376813, 39.9959649],
#                                [-75.2383741, 39.9956398],
#                                [-75.2389578, 39.9953659],
#                                [-75.2390241, 39.9953348],
#                                [-75.2394591, 39.9951306],
#                                [-75.2398632, 39.994941],
#                                [-75.2405759, 39.9946066],
#                                [-75.2410936, 39.9943636],
#                                [-75.2415363, 39.9941558],
#                                [-75.2416442, 39.9941052],
#                                [-75.2429808, 39.993478],
#                                [-75.2433182, 39.9933197],
#                                [-75.2437775, 39.9931041],
#                                [-75.2444215, 39.9928019],
#                                [-75.244981, 39.9925393],
#                                [-75.2452013, 39.9924359],
#                                [-75.2456152, 39.9922417],
#                                [-75.2456831, 39.9922098],
#                                [-75.2457615, 39.992173],
#                                [-75.2461406, 39.9919951],
#                                [-75.2471286, 39.9915314],
#                                [-75.2479989, 39.991123],
#                                [-75.2486588, 39.9908133],
#                                [-75.249091, 39.9906105],
#                                [-75.249211, 39.9905542],
#                                [-75.2493251, 39.9905023],
#                                [-75.2495393, 39.9904001],
#                                [-75.2498433, 39.9902574],
#                                [-75.2501653, 39.9901063],
#                                [-75.2508207, 39.9897987],
#                                [-75.25092, 39.9897521],
#                                [-75.2509948, 39.989717],
#                                [-75.2511594, 39.9896397],
#                                [-75.2511891, 39.9896258],
#                                [-75.2513851, 39.9895338],
#                                [-75.2514604, 39.9894985],
#                                [-75.251552, 39.9894555],
#                                [-75.2518995, 39.9892924],
#                                [-75.252094, 39.9892011],
#                                [-75.2522164, 39.9891437],
#                                [-75.2525755, 39.9889751],
#                                [-75.2530653, 39.9887453],
#                                [-75.2533625, 39.9886058],
#                                [-75.253843, 39.9883785],
#                                [-75.2539906, 39.9883105],
#                                [-75.254166, 39.9882245],
#                                [-75.2547823, 39.9879373],
#                                [-75.2556982, 39.9875105],
#                                [-75.2560625, 39.9873407],
#                                [-75.256141, 39.9873011],
#                                [-75.2562098, 39.9872584],
#                                [-75.2565115, 39.9870358],
#                                [-75.2568291, 39.9868014],
#                                [-75.257306, 39.9864495],
#                                [-75.2581301, 39.9858415],
#                                [-75.2584576, 39.9855984],
#                                [-75.2585693, 39.9855155],
#                                [-75.2586827, 39.9854313],
#                                [-75.2587255, 39.9853995],
#                                [-75.2588068, 39.9853398],
#                                [-75.25893, 39.9852689],
#                                [-75.2590647, 39.985195],
#                                [-75.2591995, 39.9851207],
#                                [-75.259496, 39.9849572],
#                                [-75.2602505, 39.9845412],
#                                [-75.2607249, 39.9842796],
#                                [-75.2608095, 39.984233],
#                                [-75.2613089, 39.9839577],
#                                [-75.2626789, 39.9832023],
#                                [-75.2632595, 39.9828821],
#                                [-75.263458, 39.9827794],
#                                [-75.2637148, 39.9826586],
#                                [-75.2639178, 39.9825683],
#                                [-75.2640155, 39.9825249],
#                                [-75.2642755, 39.9824093],
#                                [-75.2643874, 39.9823595],
#                                [-75.2644971, 39.9823108],
#                                [-75.2647856, 39.9821825],
#                                [-75.2655202, 39.981856],
#                                [-75.2656027, 39.9818193],
#                                [-75.2662612, 39.9815266],
#                                [-75.2673778, 39.9810302],
#                                [-75.267724, 39.9808763],
#                                [-75.2681096, 39.9807049],
#                                [-75.2685034, 39.9805298],
#                                [-75.2686106, 39.9804824],
#                                [-75.2691382, 39.9802492],
#                                [-75.2692581, 39.9801962],
#                                [-75.2694568, 39.9801073],
#                                [-75.2696655, 39.9800139],
#                                [-75.269732, 39.9799842],
#                                [-75.2699077, 39.9799055],
#                                [-75.2702082, 39.9797721],
#                                [-75.2706617, 39.9795703],
#                                [-75.2708504, 39.9794772],
#                                [-75.2711817, 39.9793362],
#                                [-75.2713415, 39.9792681],
#                                [-75.2715309, 39.9791839],
#                                [-75.2717188, 39.9791003],
#                                [-75.2719423, 39.979001],
#                                [-75.2722755, 39.9788528],
#                                [-75.2723598, 39.9788154],
#                                [-75.2726209, 39.9786993],
#                                [-75.2728376, 39.978603],
#                                [-75.2730377, 39.978514],
#                                [-75.2734536, 39.9783291],
#                                [-75.2735748, 39.9782753],
#                                [-75.2736619, 39.9782365],
#                                [-75.2739555, 39.978106],
#                                [-75.2741247, 39.9780308],
#                                [-75.2753017, 39.9775075],
#                                [-75.2759004, 39.9772414],
#                                [-75.2761523, 39.9771294],
#                                [-75.2764814, 39.9769753],
#                                [-75.2768054, 39.9768119],
#                                [-75.2770109, 39.9767038],
#                                [-75.2773584, 39.9765208],
#                                [-75.2776948, 39.9763438],
#                                [-75.2783481, 39.976],
#                                [-75.2785717, 39.9758823],
#                                [-75.2789674, 39.9756741],
#                                [-75.2790957, 39.9755998],
#                                [-75.2792537, 39.9755193],
#                                [-75.2796234, 39.9753288],
#                                [-75.2799089, 39.9751869],
#                                [-75.2802608, 39.97502],
#                                [-75.2802977, 39.9750019]]],
#               'type': 'Polygon'},
#   'importance': 0.7137973339835988,
#   'lat': '39.9527237',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#              'http://osm.org/copyright',
#   'lon': '-75.1635262',
#   'name': 'Philadelphia',
#   'osm_id': 188022,
#   'osm_type': 'relation',
#   'place_id': 14128726,
#   'place_rank': 16,
#   'type': 'administrative'},
#  {'addresstype': 'county',
#   'boundingbox': ['39.3114538', '40.7114538', '-75.8326504', '-74.4326504'],
#   'class': 'place',
#   'display_name': 'Philadelphia, Pennsylvania, 19140, United States',
#   'geojson': {'coordinates': [-75.1326504, 40.0114538], 'type': 'Point'},
#   'importance': 0.45000999999999997,
#   'lat': '40.0114538',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#              'http://osm.org/copyright',
#   'lon': '-75.1326504',
#   'name': 'Philadelphia',
#   'osm_id': 316987670,
#   'osm_type': 'node',
#   'place_id': 14111575,
#   'place_rank': 12,
#   'type': 'county'}]

# %% [markdown]
# ### 3.1.3 Working with CSV responses
# Sometimes API responses can be in CSV format, too. For example, the schedule data API for Center City regional arrivals by SEPTA returns CSVs. Since a CSV file is really just a text file, we can read the text from the response using a CSV reader. In the output below, showing the schedule data being displayed [here](http://www3.septa.org/ccstations/30th/) in CSV format, notice that the first line and the last two lines are not part of the table, rather messages and timestamps. Further, the CSV does not appear to have been written properly in the usual one-entry-per-line format. Rather, entries for trains on the same line are joined together. Irregularities like this are easy to miss, but can end up breaking your code.

# %%
import csv
# format: "http://www3.septa.org/ccstations/STATION/sched_data.csv", acceptable values for STATION are "me", "ss", and "30th"
schedule_response = requests.get("http://www3.septa.org/ccstations/30th/sched_data.csv")
schedule_text = schedule_response.text.strip().split("\n") # removing leading and trailing spaces and splitting lines
schedule_reader = csv.reader(schedule_text)
schedule = list(schedule_reader)
pprint(schedule)
# Out:
# [["EMG=' No Emg Message"],
#  ['R4S=09:59',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '8423  ',
#   '<_NEXT_MSG>10:07',
#   '30th St Gray',
#   '',
#   'ON TIME',
#   'LOCAL                    ',
#   '6477  ',
#   '<_NEXT_MSG>10:29',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '425   ',
#   '<_NEXT_MSG>10:59',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '8427  ',
#   ''],
#  ['R4N=10:00',
#   'Warminster',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '420   ',
#   '<_NEXT_MSG>11:00',
#   'Warminster',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '424   ',
#   '<_NEXT_MSG>12:00',
#   'Warminster',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '428   ',
#   '<_NEXT_MSG>01:00',
#   'Warminster',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '432   ',
#   ''],
#  ['R2S=10:32',
#   'Wilmington',
#   '6',
#   ' 4 LATE',
#   'LOCAL                    ',
#   '3209  ',
#   '<_NEXT_MSG>12:39',
#   'Wilmington',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '5215  ',
#   '<_NEXT_MSG>01:39',
#   'Wilmington',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '5217  ',
#   '<_NEXT_MSG>02:32',
#   'Newark',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '3219  ',
#   ''],
#  ['R3N=10:23',
#   'West Trenton',
#   '2',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '8322  ',
#   '<_NEXT_MSG>11:23',
#   'West Trenton',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '6316  ',
#   '<_NEXT_MSG>11:52',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9316  ',
#   '<_NEXT_MSG>12:23',
#   'West Trenton',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '6320  ',
#   ''],
#  ['R3S=10:03',
#   'Wawa',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '2309  ',
#   '<_NEXT_MSG>11:03',
#   'Wawa',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '2311  ',
#   '<_NEXT_MSG>11:32',
#   '30th St Gray',
#   '',
#   'ON TIME',
#   'LOCAL                    ',
#   '6313  ',
#   '<_NEXT_MSG>11:57',
#   'Wawa',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '9313  ',
#   ''],
#  ['R5N=10:12',
#   'Doylestown',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '6508  ',
#   '<_NEXT_MSG>10:15',
#   'Temple U',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '9512  ',
#   '<_NEXT_MSG>10:43',
#   'Temple U',
#   '1',
#   '12 LATE',
#   'LOCAL                    ',
#   '9544  ',
#   '<_NEXT_MSG>11:04',
#   'Doylestown',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '6510  ',
#   ''],
#  ['R5S=10:39',
#   '30th St Gray',
#   '',
#   ' 6 LATE',
#   'LOCAL                    ',
#   '6511  ',
#   '<_NEXT_MSG>10:49',
#   'Malvern',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '9513  ',
#   '<_NEXT_MSG>11:39',
#   '30th St Gray',
#   '',
#   'ON TIME',
#   'LOCAL                    ',
#   '6513  ',
#   '<_NEXT_MSG>11:55',
#   'Thorndale',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '9517  ',
#   ''],
#  ['R2N=10:25',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9208  ',
#   '<_NEXT_MSG>10:52',
#   'Norristown',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '3214  ',
#   '<_NEXT_MSG>11:03',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9212  ',
#   '<_NEXT_MSG>12:52',
#   'Norristown',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '3218  ',
#   ''],
#  ['R0=12:05',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1071  ',
#   '<_NEXT_MSG>03:21',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1081  ',
#   '<_NEXT_MSG>04:42',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1083  ',
#   '<_NEXT_MSG>06:02',
#   'Cynwyd',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '1085  ',
#   ''],
#  ['R7N=10:47',
#   'Temple U',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '9708  ',
#   '<_NEXT_MSG>11:47',
#   'Chestnut H East',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '710   ',
#   '<_NEXT_MSG>12:39',
#   'Temple U',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '9712  ',
#   '<_NEXT_MSG>01:47',
#   'Chestnut H East',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '714   ',
#   ''],
#  ['R7S=10:39',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '9711  ',
#   '<_NEXT_MSG>11:44',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '713   ',
#   '<_NEXT_MSG>12:39',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '9715  ',
#   '<_NEXT_MSG>01:44',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '717   ',
#   ''],
#  ['R8N=10:30',
#   'Fox Chase',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '4822  ',
#   '<_NEXT_MSG>11:23',
#   'Temple U',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '9826  ',
#   '<_NEXT_MSG>11:30',
#   'Fox Chase',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '4826  ',
#   '<_NEXT_MSG>12:23',
#   'Temple U',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '9830  ',
#   ''],
#  ['R8S=10:52',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '9819  ',
#   '<_NEXT_MSG>11:52',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '9823  ',
#   '<_NEXT_MSG>12:52',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '9827  ',
#   '<_NEXT_MSG>01:52',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '9831  ',
#   ''],
#  ['CC-N=10:00',
#   'Warminster',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '420   ',
#   '<_NEXT_MSG>10:12',
#   'Doylestown',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '6508  ',
#   '<_NEXT_MSG>10:15',
#   'Temple U',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '9512  ',
#   '<_NEXT_MSG>10:23',
#   'West Trenton',
#   '2',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '8322  ',
#   ''],
#  ['CC-S=09:59',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '8423  ',
#   '<_NEXT_MSG>10:03',
#   'Wawa',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '2309  ',
#   '<_NEXT_MSG>10:07',
#   '30th Street Gray',
#   '',
#   'ON TIME',
#   'LOCAL                    ',
#   '6477  ',
#   '<_NEXT_MSG>10:29',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '425   ',
#   ''],
#  ["SERVICE=' No Service Message"],
#  ['TIMESTAMP=10/31/2023 09:55:42 AM']]

# %% [markdown]
# ### 3.1.4 Working with XML Responses

# %% [markdown]
# The Wikipedia API ([docs](https://en.wikipedia.org/api/rest_v1/)) returns results to various types of calls, and notably articles, in html format. Processing an html reponse into active form is more complex than JSON---the content won't necessarily translate into a native Python data type, much like XML. To work with this, we'll want to use a module called `BeautifulSoup` (install using `pip3 install bs4`), which we'll discuss in detail when we get to web scraping in __Chapter 5__. But explore, we can request the article for Philadelphia by constructing a search query and attempt to process with `xmltodict`, as introduced in __Chapter 1__.

# %%
response = requests.get("https://en.wikipedia.org/api/rest_v1/page/html/Philadelphia Pennsylvania")
    
pprint(response.text[:10000])
# Out:
# ('<!DOCTYPE html>\n'
#  '<html prefix="dc: http://purl.org/dc/terms/ mw: http://mediawiki.org/rdf/" '
#  'about="https://en.wikipedia.org/wiki/Special:Redirect/revision/1182157691"><head '
#  'prefix="mwr: https://en.wikipedia.org/wiki/Special:Redirect/"><meta '
#  'property="mw:TimeUuid" content="2653fa40-75cc-11ee-b712-cdba7e320d1d"/><meta '
#  'charset="utf-8"/><meta property="mw:pageId" content="50585"/><meta '
#  'property="mw:pageNamespace" content="0"/><link rel="dc:replaces" '
#  'resource="mwr:revision/1181424676"/><meta property="mw:revisionSHA1" '
#  'content="79df3813a6c6f25b4d30ca9fa3e8134076a190ae"/><meta '
#  'property="dc:modified" content="2023-10-27T14:09:43.000Z"/><meta '
#  'property="mw:htmlVersion" content="2.8.0"/><meta property="mw:html:version" '
#  'content="2.8.0"/><link rel="dc:isVersionOf" '
#  'href="//en.wikipedia.org/wiki/Philadelphia"/><base '
#  'href="//en.wikipedia.org/wiki/"/><title>Philadelphia</title><meta '
#  'property="mw:jsConfigVars" '
#  'content=\'{"wgKartographerLiveData":{"_67234f47290f37689a9cf63cb45d11e4012cc904":[{"type":"ExternalData","service":"geoshape","url":"https://maps.wikimedia.org/geoshape?getgeojson=1&amp;ids=Q1345","properties":{"stroke-width":2,"stroke":"#0096FF","title":"Philadelphia","fill":"#0096FF"}},{"type":"ExternalData","service":"geomask","url":"https://maps.wikimedia.org/geoshape?getgeojson=1&amp;ids=Q1345","properties":{"title":"Philadelphia","fill-opacity":0,"stroke-opacity":0,"stroke":"#5F5F5F","stroke-width":2,"fill":"#000000"}}],"_cd19eb1a29dc89e51eb8f4d54db6d141712af91e":[{"type":"Feature","geometry":{"coordinates":[-75.163611111111,39.952777777778],"type":"Point"},"properties":{"marker-color":"5E74F3","title":"Philadelphia","marker-symbol":"city"}},{"type":"ExternalData","service":"geomask","url":"https://maps.wikimedia.org/geoshape?getgeojson=1&amp;ids=Q1400","properties":{"title":"Philadelphia","fill-opacity":0.5,"stroke-opacity":1,"stroke":"#5F5F5F","stroke-width":2,"fill":"#000000"}}],"_01e0501f36ed882f15e84f51d8b272cf5754b083":[{"type":"Feature","geometry":{"coordinates":[-75.163611111111,39.952777777778],"type":"Point"},"properties":{"marker-color":"5E74F3","title":"Philadelphia","marker-symbol":"city"}},{"type":"ExternalData","service":"geomask","url":"https://maps.wikimedia.org/geoshape?getgeojson=1&amp;ids=Q30","properties":{"title":"Philadelphia","fill-opacity":0.5,"stroke-opacity":1,"stroke":"#5F5F5F","stroke-width":2,"fill":"#000000"}}]}}\'/><meta '
#  'property="mw:generalModules" '
#  'content="ext.kartographer.staticframe|mediawiki.page.gallery|ext.cite.ux-enhancements|mediawiki.page.media"/><meta '
#  'property="mw:moduleStyles" '
#  'content="mediawiki.page.gallery.styles|ext.cite.parsoid.styles|ext.cite.styles|ext.kartographer.style"/><link '
#  'rel="stylesheet" '
#  'href="/w/load.php?lang=en&amp;modules=mediawiki.page.gallery.styles%7Cext.cite.parsoid.styles%7Cext.cite.styles%7Cext.kartographer.style%7Cmediawiki.skinning.content.parsoid%7Cmediawiki.skinning.interface%7Csite.styles&amp;only=styles&amp;skin=vector"/><meta '
#  'http-equiv="content-language" content="en"/><meta http-equiv="vary" '
#  'content="Accept"/></head><body id="mwAA" lang="en" class="mw-content-ltr '
#  'sitedir-ltr ltr mw-body-content parsoid-body mediawiki mw-parser-output" '
#  'dir="ltr"><section data-mw-section-id="0" id="mwAQ"><div '
#  'class="shortdescription nomobile noexcerpt noprint searchaux" '
#  'style="display:none" about="#mwt1" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Short '
#  'description","href":"./Template:Short_description"},"params":{"1":{"wt":"Largest '
#  'city in Pennsylvania, United States"}},"i":0}}]}\' id="mwAg">Largest city in '
#  'Pennsylvania, United States</div><link rel="mw:PageProp/Category" '
#  'href="./Category:Articles_with_short_description" about="#mwt1"/><link '
#  'rel="mw:PageProp/Category" '
#  'href="./Category:Short_description_matches_Wikidata" about="#mwt1" '
#  'id="mwAw"/>\n'
#  '<style data-mw-deduplicate="TemplateStyles:r1033289096" '
#  'typeof="mw:Extension/templatestyles mw:Transclusion" about="#mwt2" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Redirect","href":"./Template:Redirect"},"params":{"1":{"wt":"Philly"},"2":{"wt":""},"3":{"wt":"Philly '
#  '(disambiguation)"},"4":{"wt":"and"},"5":{"wt":"Philadelphia '
#  '(disambiguation)"}},"i":0}}]}\' id="mwBA">.mw-parser-output '
#  '.hatnote{font-style:italic}.mw-parser-output '
#  'div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output '
#  '.hatnote i{font-style:normal}.mw-parser-output '
#  '.hatnote+link+.hatnote{margin-top:-0.5em}</style><div role="note" '
#  'class="hatnote navigation-not-searchable" about="#mwt2" id="mwBQ">"Philly" '
#  'redirects here. For other uses, see <a rel="mw:WikiLink" '
#  'href="./Philly_(disambiguation)" title="Philly (disambiguation)" '
#  'class="mw-disambig">Philly (disambiguation)</a> and <a rel="mw:WikiLink" '
#  'href="./Philadelphia_(disambiguation)" title="Philadelphia (disambiguation)" '
#  'class="mw-disambig">Philadelphia (disambiguation)</a>.</div>\n'
#  '<p id="mwBg"><span typeof="mw:Nowiki mw:Transclusion" about="#mwt5" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"pp-semi-indef","href":"./Template:Pp-semi-indef"},"params":{},"i":0}}]}\' '
#  'id="mwBw"></span><meta typeof="mw:Extension/indicator" about="#mwt5" '
#  'data-mw=\'{"name":"indicator","attrs":{"name":"pp-default"},"body":{"extsrc":"[[File:Semi-protection-shackle.svg|20px|link=Wikipedia:Protection '
#  'policy#semi|alt=Page semi-protected|This article is '
#  'semi-protected.]]"},"html":"&lt;span typeof=\\"mw:File\\" '
#  'data-parsoid=&apos;{\\"optList\\":[{\\"ck\\":\\"width\\",\\"ak\\":\\"20px\\"},{\\"ck\\":\\"link\\",\\"ak\\":\\"link=Wikipedia:Protection '
#  'policy#semi\\"},{\\"ck\\":\\"alt\\",\\"ak\\":\\"alt=Page '
#  'semi-protected\\"},{\\"ck\\":\\"caption\\",\\"ak\\":\\"This article is '
#  'semi-protected.\\"}]}&apos; data-mw=&apos;{\\"caption\\":\\"This article is '
#  'semi-protected.\\"}&apos;>&lt;a '
#  'href=\\"./Wikipedia:Protection_policy#semi\\" title=\\"This article is '
#  'semi-protected.\\" data-parsoid=\\"{}\\">&lt;img alt=\\"Page '
#  'semi-protected\\" resource=\\"./File:Semi-protection-shackle.svg\\" '
#  'src=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png\\" '
#  'decoding=\\"async\\" data-file-width=\\"512\\" data-file-height=\\"512\\" '
#  'data-file-type=\\"drawing\\" height=\\"20\\" width=\\"20\\" '
#  'srcset=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png '
#  '1.5x, '
#  '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png '
#  '2x\\" class=\\"mw-file-element\\" '
#  'data-parsoid=&apos;{\\"a\\":{\\"resource\\":\\"./File:Semi-protection-shackle.svg\\",\\"height\\":\\"20\\",\\"width\\":\\"20\\"},\\"sa\\":{\\"resource\\":\\"File:Semi-protection-shackle.svg\\"}}&apos;/>&lt;/a>&lt;/span>"}\' '
#  'id="mwCA"/><link rel="mw:PageProp/Category" '
#  'href="./Category:Wikipedia_indefinitely_semi-protected_pages#Philadelphia" '
#  'about="#mwt5" id="mwCQ"/>\n'
#  '<link rel="mw:PageProp/Category" '
#  'href="./Category:Wikipedia_indefinitely_move-protected_pages#Philadelphia" '
#  'about="#mwt9" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"pp-move","href":"./Template:Pp-move"},"params":{},"i":0}}]}\' '
#  'id="mwCg"/>\n'
#  '<span typeof="mw:Nowiki mw:Transclusion" about="#mwt10" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Use mdy '
#  'dates","href":"./Template:Use_mdy_dates"},"params":{"date":{"wt":"November '
#  '2022"}},"i":0}}]}\' id="mwCw"></span><link rel="mw:PageProp/Category" '
#  'href="./Category:Use_mdy_dates_from_November_2022" about="#mwt10" '
#  'id="mwDA"/></p>\n'
#  '<div class="shortdescription nomobile noexcerpt noprint searchaux" '
#  'style="display:none" about="#mwt23" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Infobox '
#  'settlement\\n","href":"./Template:Infobox_settlement"},"params":{"name":{"wt":"Philadelphia"},"settlement_type":{"wt":"[[Consolidated '
#  'city-county]]"},"etymology":{"wt":"[[Ancient Greek]]: [[wikt:φίλος|φίλος]] '
#  '&apos;&apos;phílos&apos;&apos; (beloved, dear) and [[wikt:ἀδελφός|ἀδελφός]] '
#  '&apos;&apos;adelphós&apos;&apos; (brother, '
#  'brotherly)&lt;br/>———-———&lt;br/>"},"image_skyline":{"wt":"{{multiple '
#  'image\\n  | border                   = infobox\\n  | '
#  'total_width              = 290\\n  | perrow                   = 1/2/2/1\\n  '
#  '| caption_align            = center\\n  | image1                   = '
#  'Philadelphia skyline from South Street Bridge January 2020 (rotate 2 degrees '
#  'perspective correction crop 4-1).jpg\\n  | alt1                     = '
#  'Skyline of Center City\\n  | caption1                 = Skyline of [[Center '
#  'City (Philadelphia)  |Center City]]\\n  | image2                   = '
#  'Independence National Historical Park INDE0004 b.jpg\\n  | '
#  'alt2                     = Independence National Historical Park\\n  | '
#  'caption2                 = [[Independence National Historical Park]]\\n  | '
#  'image3                   = Philadelphia City Hall, aerial view, '
#  'cropped.png\\n  | alt3                     = Philadelphia City Hall\\n  | '
#  'caption3                 = [[Philadelphia City Hall]] \\n  | '
#  'image4                   = Locust Walk by Wharton.jpg\\n  | '
#  'alt4                     = University of Pennsylvania campus\\n  | '
#  'caption4                 = [[University of Pennsylvania]] campus\\n  | '
#  'image5                   = Elfreth&apos;s Alley 2.JPG\\n  | '
#  'alt5                     = Elfreth&apos;s Alley\\n  | '
#  'caption5                 = [[Elfreth&apos;s Alley]]\\n  | '
#  'image6                   = PhiladelphiaMuseumOfArt2017.jpg\\n  | '
#  'alt6                     = Philadelphia Museum of Art\\n  | '
#  'caption6                 = [[Philadelphia Museum of '
#  'Art]]\\n}}"},"nickname":{"wt":"\\"Philly\\", \\"The City of Brotherly '
#  'Love\\", \\"America&apos;s [[Garden]] Capital\\",&lt;ref>{{cite '
#  'web|url=http://americasgardencapital.org/|title=Philadelphia, America&apos;s '
#  'Garden Capital|quote=With a tradition of horticulture going back 300 years, '
#  'Philadelphia is America&apos;s Garden Capital.|publisher=America&apos;s '
#  'garden capital.org.access-date=October 22, 2022|access-date=October 23, '
#  '2022|archive-date=October 23, '
#  '2022|archive-url=https://web.archive.org/web/20221023022440/http://americasgardencapital.org/|url-status=live}}&lt;/ref> '
#  '\\"The [[Athens]] of America\\",&lt;ref>{{cite '
#  'web|url=http://www.librarycompany.org/artifacts/athens.htm|titl')

# %% [markdown]
# Since html is essentially a type of XML, we can try and convert the response into a dictionary using `xmltodict`. As you can see, in order to get the desired data out of the html, some studying of its structure is necessary. And since the structure of an html document is so particular, it will turn out to be a bit easier working with the html-specific parser in `BeautifulSoup` (__Chapter 5__). However, as we can see the content is there and navigable!

# %%
import xmltodict

parsed = xmltodict.parse(response.text)
pprint(parsed['html']['body']['section'][0])
# Out:
# {'@data-mw-section-id': '0',
#  '@id': 'mwAQ',
#  'div': [{'#text': 'Largest city in Pennsylvania, United States',
#           '@about': '#mwt1',
#           '@class': 'shortdescription nomobile noexcerpt noprint searchaux',
#           '@data-mw': '{"parts":[{"template":{"target":{"wt":"Short '
#                       'description","href":"./Template:Short_description"},"params":{"1":{"wt":"Largest '
#                       'city in Pennsylvania, United States"}},"i":0}}]}',
#           '@id': 'mwAg',
#           '@style': 'display:none',
#           '@typeof': 'mw:Transclusion'},
#          {'#text': '"Philly" redirects here. For other uses, see  and .',
#           '@about': '#mwt2',
#           '@class': 'hatnote navigation-not-searchable',
#           '@id': 'mwBQ',
#           '@role': 'note',
#           'a': [{'#text': 'Philly (disambiguation)',
#                  '@class': 'mw-disambig',
#                  '@href': './Philly_(disambiguation)',
#                  '@rel': 'mw:WikiLink',
#                  '@title': 'Philly (disambiguation)'},
#                 {'#text': 'Philadelphia (disambiguation)',
#                  '@class': 'mw-disambig',
#                  '@href': './Philadelphia_(disambiguation)',
#                  '@rel': 'mw:WikiLink',
#                  '@title': 'Philadelphia (disambiguation)'}]},
#          {'#text': 'Consolidated city-county in the United States',
#           '@about': '#mwt23',
#           '@class': 'shortdescription nomobile noexcerpt noprint searchaux',
#           '@data-mw': '{"parts":[{"template":{"target":{"wt":"Infobox '
#                       'settlement\\n","href":"./Template:Infobox_settlement"},"params":{"name":{"wt":"Philadelphia"},"settlement_type":{"wt":"[[Consolidated '
#                       'city-county]]"},"etymology":{"wt":"[[Ancient Greek]]: '
#                       "[[wikt:φίλος|φίλος]] ''phílos'' (beloved, dear) and "
#                       "[[wikt:ἀδελφός|ἀδελφός]] ''adelphós'' (brother, "
#                       'brotherly)<br/>———-———<br/>"},"image_skyline":{"wt":"{{multiple '
#                       'image\\n  | border                   = infobox\\n  | '
#                       'total_width              = 290\\n  | '
#                       'perrow                   = 1/2/2/1\\n  | '
#                       'caption_align            = center\\n  | '
#                       'image1                   = Philadelphia skyline from '
#                       'South Street Bridge January 2020 (rotate 2 degrees '
#                       'perspective correction crop 4-1).jpg\\n  | '
#                       'alt1                     = Skyline of Center City\\n  | '
#                       'caption1                 = Skyline of [[Center City '
#                       '(Philadelphia)  |Center City]]\\n  | '
#                       'image2                   = Independence National '
#                       'Historical Park INDE0004 b.jpg\\n  | '
#                       'alt2                     = Independence National '
#                       'Historical Park\\n  | caption2                 = '
#                       '[[Independence National Historical Park]]\\n  | '
#                       'image3                   = Philadelphia City Hall, '
#                       'aerial view, cropped.png\\n  | alt3                     '
#                       '= Philadelphia City Hall\\n  | caption3                 '
#                       '= [[Philadelphia City Hall]] \\n  | '
#                       'image4                   = Locust Walk by '
#                       'Wharton.jpg\\n  | alt4                     = University '
#                       'of Pennsylvania campus\\n  | caption4                 = '
#                       '[[University of Pennsylvania]] campus\\n  | '
#                       "image5                   = Elfreth's Alley 2.JPG\\n  | "
#                       "alt5                     = Elfreth's Alley\\n  | "
#                       "caption5                 = [[Elfreth's Alley]]\\n  | "
#                       'image6                   = '
#                       'PhiladelphiaMuseumOfArt2017.jpg\\n  | '
#                       'alt6                     = Philadelphia Museum of '
#                       'Art\\n  | caption6                 = [[Philadelphia '
#                       'Museum of Art]]\\n}}"},"nickname":{"wt":"\\"Philly\\", '
#                       '\\"The City of Brotherly Love\\", \\"America\'s '
#                       '[[Garden]] Capital\\",<ref>{{cite '
#                       'web|url=http://americasgardencapital.org/|title=Philadelphia, '
#                       "America's Garden Capital|quote=With a tradition of "
#                       'horticulture going back 300 years, Philadelphia is '
#                       "America's Garden Capital.|publisher=America's garden "
#                       'capital.org.access-date=October 22, '
#                       '2022|access-date=October 23, 2022|archive-date=October '
#                       '23, '
#                       '2022|archive-url=https://web.archive.org/web/20221023022440/http://americasgardencapital.org/|url-status=live}}</ref> '
#                       '\\"The [[Athens]] of America\\",<ref>{{cite '
#                       'web|url=http://www.librarycompany.org/artifacts/athens.htm|title=Art '
#                       "& Artifacts: Discover the Library Company's Art and "
#                       'Artifact Collection – Athens of '
#                       'America|website=librarycompany.org|publisher=The '
#                       'Library Company of Philadelphia|access-date=June 12, '
#                       '2010|archive-date=May 5, '
#                       '2021|archive-url=https://web.archive.org/web/20210505225944/http://librarycompany.org/artifacts/athens.htm|url-status=live}}</ref> '
#                       'and other [[nicknames of '
#                       'Philadelphia]]<br/>———-———<br/>"},"motto":{"wt":"\\"Philadelphia '
#                       'maneto\\" (\\"Let brotherly love endure\\" or \\"... '
#                       'continue\\")<ref>{{cite '
#                       'web|last=Robinson|first=Sam|date=November 5, '
#                       '2013|url=https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal|title=Behind '
#                       'Philadelphia Maneto: Dissecting The City '
#                       'Seal|website=Hidden City '
#                       'Philadelphia|access-date=January 18, '
#                       '2018|archive-date=January 19, '
#                       '2018|archive-url=https://web.archive.org/web/20180119040015/https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal/|url-status=live}}</ref><ref>{{cite '
#                       'web|last=McDevitt|first=John|date=May 5, '
#                       '2015|url=http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks-120th-anniversary-of-creation-of-philadelphias-flag/|title=Plaque '
#                       'Dedication Marks 120th Anniversary of Creation of '
#                       "Philadelphia's Flag|website=CBS Broadcasting "
#                       'Inc.|access-date=January 18, 2018|archive-date=January '
#                       '19, '
#                       '2018|archive-url=https://web.archive.org/web/20180119035613/http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks-120th-anniversary-of-creation-of-philadelphias-flag/|url-status=live}}</ref>"},"image_flag":{"wt":"Flag '
#                       'of Philadelphia, '
#                       'Pennsylvania.svg"},"image_seal":{"wt":"Seal of '
#                       'Philadelphia, '
#                       'Pennsylvania.svg"},"image_blank_emblem":{"wt":"City of '
#                       'Philadelphia '
#                       'Logo.svg"},"blank_emblem_size":{"wt":"150px"},"blank_emblem_type":{"wt":"Logo"},"image_map":{"wt":"{{maplink\\n  '
#                       '| frame                    = yes\\n  | '
#                       'plain                    = yes\\n  | '
#                       'frame-align              = center\\n  | '
#                       'frame-width              = 280\\n  | '
#                       'frame-height             = 280\\n  | '
#                       'frame-coord              = '
#                       'SWITCH:{{coord|39|59|40|N|75|6|49|W}}###{{coord|qid=Q1400}}###{{coord|qid=Q30}}\\n  '
#                       '| zoom                     = SWITCH:10;6;3\\n  | '
#                       'type                     = SWITCH:shape;point;point\\n  '
#                       '| marker                   = city\\n  | '
#                       'stroke-width             = 2\\n  | '
#                       'stroke-color             = #0096FF\\n  | '
#                       'fill                     = #0096FF\\n  | '
#                       'id2                      = SWITCH:Q1345;Q1400;Q30\\n  | '
#                       'type2                    = shape-inverse\\n  | '
#                       'stroke-width2            = 2\\n  | '
#                       'stroke-color2            = #5F5F5F\\n  | '
#                       'stroke-opacity2          = SWITCH:0;1;1\\n  | '
#                       'fill2                    = #000000\\n  | '
#                       'fill-opacity2            = SWITCH:0;0.5;0.5\\n  | '
#                       'switch                   = '
#                       'Philadelphia;Pennsylvania;the United '
#                       'States\\n}}"},"subdivision_type":{"wt":"Country"},"subdivision_type2":{"wt":"State"},"subdivision_type3":{"wt":"[[List '
#                       'of counties in '
#                       'Pennsylvania|County]]"},"subdivision_name":{"wt":"United '
#                       'States"},"subdivision_name2":{"wt":"[[Pennsylvania]]"},"subdivision_name3":{"wt":"[[Philadelphia '
#                       'County, '
#                       'Pennsylvania|Philadelphia]]"},"subdivision_type4":{"wt":"Historic '
#                       'countries"},"subdivision_name4":{"wt":"[[Kingdom of '
#                       'England]]<br />[[Kingdom of Great '
#                       'Britain]]"},"subdivision_type5":{"wt":"[[Colony|Historic '
#                       'colony]]"},"subdivision_name5":{"wt":"[[Province of '
#                       'Pennsylvania]]"},"government_type":{"wt":"[[Mayor–council '
#                       'government|Mayor–council]], [[consolidated '
#                       'city-county]]"},"governing_body":{"wt":"[[Philadelphia '
#                       'City Council]]"},"leader_title":{"wt":"[[List of mayors '
#                       'of Philadelphia|Mayor]]"},"leader_name":{"wt":"[[Jim '
#                       'Kenney]] ([[Democratic Party (United '
#                       'States)|D]])"},"established_title":{"wt":"Founded"},"established_title1":{"wt":"[[Municipal '
#                       'corporation|Incorporated]]"},"established_date":{"wt":"{{Start '
#                       'date and age|1682}}<ref name=weigley/><!-- ref states '
#                       'early 1862 for first land purchase and summer 1682 for '
#                       "initial survey by Penn's surveyor-general, Thomas "
#                       "Holme, before Penn's arrival in October; no exact dates "
#                       'are given -->"},"established_date1":{"wt":"October 25, '
#                       '1701"},"founder":{"wt":"[[William '
#                       'Penn]]"},"unit_pref":{"wt":"Imperial"},"area_total_sq_mi":{"wt":"142.70"},"area_total_km2":{"wt":"369.59"},"area_land_sq_mi":{"wt":"134.36"},"area_land_km2":{"wt":"347.98"},"area_water_sq_mi":{"wt":"8.34"},"area_water_km2":{"wt":"21.61"},"population_as_of":{"wt":"[[2020 '
#                       'United States '
#                       'census|2020]]"},"population_footnotes":{"wt":"<ref '
#                       'name=\\"USCensusDecennial2020CenPopScriptOnly\\">{{cite '
#                       'web|url=https://api.census.gov/data/2020/dec/pl?get=P1_001N,NAME&for=place:*&in=state:42&key=5ccd0821c15d9f4520e2dcc0f8d92b2ec9336108|title=Census '
#                       'Population API|publisher=United States Census '
#                       'Bureau|accessdate=October 16, '
#                       '2022|archive-date=November 9, '
#                       '2022|archive-url=https://web.archive.org/web/20221109154513/https://api.census.gov/data/2020/dec/pl?get=P1_001N,NAME&for=place:*&in=state:42&key=5ccd0821c15d9f4520e2dcc0f8d92b2ec9336108|url-status=live}}</ref>"},"population_total":{"wt":"1,603,797"},"population_est":{"wt":"1,567,258"},"pop_est_as_of":{"wt":"2022"},"pop_est_footnotes":{"wt":"<ref '
#                       'name=\\"QuickFacts city\\">{{cite '
#                       'web|url=https://www.census.gov/quickfacts/fact/table/philadelphiacitypennsylvania/PST045222|title=QuickFacts: '
#                       'Philadelphia city, '
#                       'Pennsylvania|website=census.gov|publisher=United States '
#                       'Census Bureau|access-date=14 July '
#                       '2023|archive-date=January 31, '
#                       '2023|archive-url=https://web.archive.org/web/20230131031345/https://www.census.gov/quickfacts/fact/table/philadelphiacitypennsylvania/PST045222|url-status=live}}</ref>"},"population_rank":{"wt":"[[List '
#                       'of North American cities by population|10th]] in North '
#                       'America<br />[[List of United States cities by '
#                       'population|6th]] in the United States<br />[[List of '
#                       'cities and boroughs in Pennsylvania by population|1st]] '
#                       'in '
#                       'Pennsylvania"},"population_metro_footnotes":{"wt":"<ref '
#                       'name=\\"2020Pop\\">{{cite web |title=2020 Population '
#                       'and Housing State Data '
#                       '|url=https://www.census.gov/library/visualizations/interactive/2020-population-and-housing-state-data.html '
#                       '|publisher=United States Census Bureau '
#                       '|access-date=August 22, 2021 |archive-date=August 24, '
#                       '2021 '
#                       '|archive-url=https://web.archive.org/web/20210824081449/https://www.census.gov/library/visualizations/interactive/2020-population-and-housing-state-data.html '
#                       '|url-status=live '
#                       '}}</ref>"},"population_metro":{"wt":"6245051 (US: '
#                       '[[List of metropolitan statistical '
#                       'areas|7th]])"},"population_density_sq_mi":{"wt":"11936.92"},"population_density_km2":{"wt":"4608.86"},"population_urban":{"wt":"5,696,125 '
#                       '(US: [[List of United States urban '
#                       'areas|7th]])"},"population_density_urban_km2":{"wt":"1,158.6"},"population_density_urban_sq_mi":{"wt":"3,000.8"},"population_urban_footnotes":{"wt":"<ref '
#                       'name=\\"urban area\\">{{cite '
#                       'web|url=https://www.census.gov/programs-surveys/geography/guidance/geo-areas/urban-rural.html|title=List '
#                       'of 2020 Census Urban '
#                       'Areas|website=census.gov|publisher=United States Census '
#                       'Bureau|access-date=January 8, 2023|archive-date=January '
#                       '14, '
#                       '2023|archive-url=https://web.archive.org/web/20230114022812/https://www.census.gov/programs-surveys/geography/guidance/geo-areas/urban-rural.html|url-status=live}}</ref>"},"population_demonym":{"wt":"Philadelphian"},"timezone":{"wt":"[[North '
#                       'American Eastern Time '
#                       'Zone|EST]]"},"utc_offset":{"wt":"−5"},"timezone_DST":{"wt":"[[Eastern '
#                       'Daylight '
#                       'Time|EDT]]"},"utc_offset_DST":{"wt":"−4"},"postal_code_type":{"wt":"[[ZIP '
#                       'Code]]s"},"postal_code":{"wt":"19092–19093, 19099, '
#                       '191xx"},"area_codes":{"wt":"[[Area codes 215, 267, and '
#                       '445|215, 267, '
#                       '445]]"},"coordinates":{"wt":"{{coord|39|57|10|N|75|09|49|W|format=dms|region:US-PA_type:city(1,600,000)|display=inline,title}}"},"elevation_m":{"wt":"12"},"elevation_ft":{"wt":"39"},"blank_name":{"wt":"[[Federal '
#                       'Information Processing Standards|FIPS '
#                       'code]]"},"blank_info":{"wt":"42-60000"},"blank1_name":{"wt":"[[Geographic '
#                       'Names Information System|GNIS]] feature '
#                       'ID"},"blank1_info":{"wt":"1215531<ref>{{cite '
#                       'web|url=http://geonames.usgs.gov/apex/f?p=136:3:0::NO::P3_FID,P3_TITLE:1215531,City%20of%20Philadelphia|access-date=January '
#                       '31, 2008|title=US Board on Geographic '
#                       'Names|publisher=[[United States Geological '
#                       'Survey]]|date=February 2, 2015|archive-date=October 27, '
#                       '2023|archive-url=https://web.archive.org/web/20231027140852/https://www.usgs.gov/us-board-on-geographic-names/domestic-names?p=136%3A3%3A0%3A%3ANO%3A%3AP3_FID%2CP3_TITLE%3A1215531%2CCity%2520of%2520Philadelphia|url-status=live}}</ref>"},"website":{"wt":"[http://www.phila.gov/ '
#                       'www.phila.gov]"},"footnotes":{"wt":""},"area_footnotes":{"wt":"<ref '
#                       'name=\\"TigerWebMapServer\\">{{cite web|title=ArcGIS '
#                       'REST Services '
#                       'Directory|url=https://tigerweb.geo.census.gov/arcgis/rest/services/TIGERweb/Places_CouSub_ConCity_SubMCD/MapServer/5/query?where=STATE%3D%2742%27&outFields=NAME%2CSTATE%2CPLACE%2CAREALAND%2CAREAWATER%2CLSADC%2CCENTLAT%2CCENTLON&orderByFields=PLACE&returnGeometry=false&returnTrueCurves=false&f=json|publisher=United '
#                       'States Census Bureau|accessdate=October 16, '
#                       '2022|archive-date=November 9, '
#                       '2022|archive-url=https://web.archive.org/web/20221109154513/https://tigerweb.geo.census.gov/arcgis/rest/services/TIGERweb/Places_CouSub_ConCity_SubMCD/MapServer/5/query?where=STATE%3D%2742%27&outFields=NAME%2CSTATE%2CPLACE%2CAREALAND%2CAREAWATER%2CLSADC%2CCENTLAT%2CCENTLON&orderByFields=PLACE&returnGeometry=false&returnTrueCurves=false&f=json|url-status=live}}</ref>"}},"i":0}}]}',
#           '@id': 'mwDQ',
#           '@style': 'display:none',
#           '@typeof': 'mw:Transclusion'},
#          {'@about': '#mwt294',
#           '@class': 'toclimit-3',
#           '@id': 'mw7Q',
#           'meta': {'@property': 'mw:PageProp/toc'}}],
#  'link': [{'@about': '#mwt1',
#            '@href': './Category:Articles_with_short_description',
#            '@rel': 'mw:PageProp/Category'},
#           {'@about': '#mwt1',
#            '@href': './Category:Short_description_matches_Wikidata',
#            '@id': 'mwAw',
#            '@rel': 'mw:PageProp/Category'},
#           {'@about': '#mwt23',
#            '@href': './Category:Articles_with_short_description',
#            '@rel': 'mw:PageProp/Category'},
#           {'@about': '#mwt23',
#            '@href': './Category:Short_description_is_different_from_Wikidata',
#            '@rel': 'mw:PageProp/Category'}],
#  'p': [{'@id': 'mwBg',
#         'link': [{'@about': '#mwt5',
#                   '@href': './Category:Wikipedia_indefinitely_semi-protected_pages#Philadelphia',
#                   '@id': 'mwCQ',
#                   '@rel': 'mw:PageProp/Category'},
#                  {'@about': '#mwt9',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"pp-move","href":"./Template:Pp-move"},"params":{},"i":0}}]}',
#                   '@href': './Category:Wikipedia_indefinitely_move-protected_pages#Philadelphia',
#                   '@id': 'mwCg',
#                   '@rel': 'mw:PageProp/Category',
#                   '@typeof': 'mw:Transclusion'},
#                  {'@about': '#mwt10',
#                   '@href': './Category:Use_mdy_dates_from_November_2022',
#                   '@id': 'mwDA',
#                   '@rel': 'mw:PageProp/Category'}],
#         'meta': {'@about': '#mwt5',
#                  '@data-mw': '{"name":"indicator","attrs":{"name":"pp-default"},"body":{"extsrc":"[[File:Semi-protection-shackle.svg|20px|link=Wikipedia:Protection '
#                              'policy#semi|alt=Page semi-protected|This article '
#                              'is semi-protected.]]"},"html":"<span '
#                              'typeof=\\"mw:File\\" '
#                              'data-parsoid=\'{\\"optList\\":[{\\"ck\\":\\"width\\",\\"ak\\":\\"20px\\"},{\\"ck\\":\\"link\\",\\"ak\\":\\"link=Wikipedia:Protection '
#                              'policy#semi\\"},{\\"ck\\":\\"alt\\",\\"ak\\":\\"alt=Page '
#                              'semi-protected\\"},{\\"ck\\":\\"caption\\",\\"ak\\":\\"This '
#                              'article is semi-protected.\\"}]}\' '
#                              'data-mw=\'{\\"caption\\":\\"This article is '
#                              'semi-protected.\\"}\'><a '
#                              'href=\\"./Wikipedia:Protection_policy#semi\\" '
#                              'title=\\"This article is semi-protected.\\" '
#                              'data-parsoid=\\"{}\\"><img alt=\\"Page '
#                              'semi-protected\\" '
#                              'resource=\\"./File:Semi-protection-shackle.svg\\" '
#                              'src=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png\\" '
#                              'decoding=\\"async\\" data-file-width=\\"512\\" '
#                              'data-file-height=\\"512\\" '
#                              'data-file-type=\\"drawing\\" height=\\"20\\" '
#                              'width=\\"20\\" '
#                              'srcset=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png '
#                              '1.5x, '
#                              '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png '
#                              '2x\\" class=\\"mw-file-element\\" '
#                              'data-parsoid=\'{\\"a\\":{\\"resource\\":\\"./File:Semi-protection-shackle.svg\\",\\"height\\":\\"20\\",\\"width\\":\\"20\\"},\\"sa\\":{\\"resource\\":\\"File:Semi-protection-shackle.svg\\"}}\'/></a></span>"}',
#                  '@id': 'mwCA',
#                  '@typeof': 'mw:Extension/indicator'},
#         'span': [{'@about': '#mwt5',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"pp-semi-indef","href":"./Template:Pp-semi-indef"},"params":{},"i":0}}]}',
#                   '@id': 'mwBw',
#                   '@typeof': 'mw:Nowiki mw:Transclusion'},
#                  {'@about': '#mwt10',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"Use mdy '
#                               'dates","href":"./Template:Use_mdy_dates"},"params":{"date":{"wt":"November '
#                               '2022"}},"i":0}}]}',
#                   '@id': 'mwCw',
#                   '@typeof': 'mw:Nowiki mw:Transclusion'}]},
#        {'#text': ', commonly referred to as , is the  in the  of  and the '
#                  'second-most populous city in both the  and  regions after . '
#                  'It is one of the most historically significant cities in '
#                  'the  and served as the  until . Philadelphia is the  with a '
#                  'population of 1,603,797 as of the . , the city has been '
#                  'coextensive with , the . Philadelphia serves as the urban '
#                  'core of the larger  (or Philadelphia metropolitan area), '
#                  'the  and one of the   consisting of 6.245 million residents '
#                  'in the  and 7.366 million residents in its . Philadelphia is '
#                  'known for its extensive contributions to American , '
#                  'especially the , and for its contemporary influence in , , , '
#                  'and .',
#         '@id': 'mwLA',
#         'a': [{'#text': 'most populous city',
#                '@href': './List_of_municipalities_in_Pennsylvania',
#                '@id': 'mwLw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of municipalities in Pennsylvania'},
#               {'#text': 'U.S. Commonwealth',
#                '@href': './Commonwealth_(U.S._state)',
#                '@id': 'mwMA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Commonwealth (U.S. state)'},
#               {'#text': 'Pennsylvania',
#                '@href': './Pennsylvania',
#                '@id': 'mwMQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Pennsylvania'},
#               {'#text': 'Northeast megalopolis',
#                '@href': './Northeast_megalopolis',
#                '@id': 'mwNA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Northeast megalopolis'},
#               {'#text': 'Mid-Atlantic',
#                '@href': './Mid-Atlantic_(United_States)',
#                '@id': 'mwNQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Mid-Atlantic (United States)'},
#               {'#text': 'New York City',
#                '@href': './New_York_City',
#                '@id': 'mwNg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'New York City'},
#               {'#text': 'United States',
#                '@href': './United_States',
#                '@id': 'mwNw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'United States'},
#               {'#text': "nation's capital",
#                '@href': './List_of_capitals_in_the_United_States',
#                '@id': 'mwOA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of capitals in the United States'},
#               {'#text': '1800',
#                '@href': './1800_in_the_United_States',
#                '@id': 'mwOQ',
#                '@rel': 'mw:WikiLink',
#                '@title': '1800 in the United States'},
#               {'#text': "nation's sixth-most populous city",
#                '@href': './List_of_United_States_cities_by_population',
#                '@id': 'mwPA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of United States cities by population'},
#               {'#text': '2020 census',
#                '@href': './2020_United_States_census',
#                '@id': 'mwPQ',
#                '@rel': 'mw:WikiLink',
#                '@title': '2020 United States census'},
#               {'#text': 'Since 1854',
#                '@href': './Act_of_Consolidation,_1854',
#                '@id': 'mwPg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Act of Consolidation, 1854'},
#               {'#text': 'Philadelphia County',
#                '@href': './Philadelphia_County,_Pennsylvania',
#                '@id': 'mwPw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Philadelphia County, Pennsylvania'},
#               {'#text': 'most populous county in Pennsylvania',
#                '@href': './List_of_counties_in_Pennsylvania',
#                '@id': 'mwQA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of counties in Pennsylvania'},
#               {'#text': 'Delaware Valley',
#                '@href': './Delaware_Valley',
#                '@id': 'mwQQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Delaware Valley'},
#               {'#text': "nation's seventh-largest",
#                '@href': './Metropolitan_statistical_area',
#                '@id': 'mwQg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Metropolitan statistical area'},
#               {'#text': "world's largest",
#                '@href': './List_of_largest_cities',
#                '@id': 'mwQw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of largest cities'},
#               {'#text': 'metropolitan regions',
#                '@class': 'mw-redirect',
#                '@href': './Metropolitan_region',
#                '@id': 'mwRA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Metropolitan region'},
#               {'#text': 'metropolitan statistical area',
#                '@href': './Metropolitan_statistical_area',
#                '@id': 'mwRQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Metropolitan statistical area'},
#               {'#text': 'combined statistical area',
#                '@href': './Combined_statistical_area',
#                '@id': 'mwRg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Combined statistical area'},
#               {'#text': 'history',
#                '@href': './History_of_Philadelphia',
#                '@id': 'mwSQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'History of Philadelphia'},
#               {'#text': 'American Revolution',
#                '@href': './American_Revolution',
#                '@id': 'mwSg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'American Revolution'},
#               {'#text': 'business and industry',
#                '@href': './Economy_of_Philadelphia',
#                '@id': 'mwSw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Economy of Philadelphia'},
#               {'#text': 'culture',
#                '@href': './Culture_of_Philadelphia',
#                '@id': 'mwTA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Culture of Philadelphia'},
#               {'#text': 'sports',
#                '@href': './Sports_in_Philadelphia',
#                '@id': 'mwTQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Sports in Philadelphia'},
#               {'#text': 'music',
#                '@href': './Music_of_Philadelphia',
#                '@id': 'mwTg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Music of Philadelphia'}],
#         'b': [{'#text': 'Philadelphia', '@id': 'mwLQ'},
#               {'#text': 'Philly', '@id': 'mwLg'}],
#         'sup': [{'@about': '#mwt106',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{"name":"QuickFacts"},"body":{"id":"mw-reference-text-cite_note-QuickFacts-12"}}',
#                  '@id': 'cite_ref-QuickFacts_12-0',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-QuickFacts-12',
#                        '@id': 'mwMg',
#                        '@style': 'counter-reset: mw-Ref 12;',
#                        'span': {'#text': '[12]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwMw'}}},
#                 {'@about': '#mwt110',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-13"}}',
#                  '@id': 'cite_ref-13',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-13',
#                        '@id': 'mwOg',
#                        '@style': 'counter-reset: mw-Ref 13;',
#                        'span': {'#text': '[13]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwOw'}}},
#                 {'@about': '#mwt114',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-14"}}',
#                  '@id': 'cite_ref-14',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-14',
#                        '@id': 'mwRw',
#                        '@style': 'counter-reset: mw-Ref 14;',
#                        'span': {'#text': '[14]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwSA'}}},
#                 {'@about': '#mwt118',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-15"}}',
#                  '@id': 'cite_ref-15',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-15',
#                        '@id': 'mwTw',
#                        '@style': 'counter-reset: mw-Ref 15;',
#                        'span': {'#text': '[15]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwUA'}}},
#                 {'@about': '#mwt122',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-16"}}',
#                  '@id': 'cite_ref-16',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-16',
#                        '@id': 'mwUQ',
#                        '@style': 'counter-reset: mw-Ref 16;',
#                        'span': {'#text': '[16]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwUg'}}}]},
#        {'#text': 'Philadelphia was founded in 1682 by , an   and advocate of . '
#                  'The city served as the capital of the  during the  and went '
#                  'on to play a historic and vital role as the central meeting '
#                  'place for the  whose plans and actions in Philadelphia '
#                  "ultimately inspired the American Revolution and the nation's "
#                  'independence following the . Philadelphia hosted the  in '
#                  '1774, preserved the , and hosted the  during which the '
#                  'founders signed the , which historian  has described as "the '
#                  'most potent and consequential words in American history". '
#                  'Once the Revolutionary War commenced, the  and the  were '
#                  "fought within Philadelphia's city limits. The  was later "
#                  'ratified in Philadelphia at the  of 1787. Philadelphia '
#                  "remained the nation's largest city until 1790, when it was "
#                  "surpassed by New York City, and it served as the nation's "
#                  'first capital from May 10, 1775, until December 12, 1776, '
#                  'and on four subsequent occasions during and following the '
#                  'American Revolution, including from 1790 to 1800 during the '
#                  'construction of the new national capital of',
#         '@id': 'mwUw',
#         'a': [{'#text': 'William Penn',
#                '@href': './William_Penn',
#                '@id': 'mwVA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'William Penn'},
#               {'#text': 'English',
#                '@href': './English_Americans',
#                '@id': 'mwVQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'English Americans'},
#               {'#text': 'Quaker',
#                '@href': './Quakers',
#                '@id': 'mwVg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Quakers'},
#               {'#text': 'religious freedom',
#                '@href': './Freedom_of_religion',
#                '@id': 'mwVw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Freedom of religion'},
#               {'#text': 'Pennsylvania Colony',
#                '@href': './Province_of_Pennsylvania',
#                '@id': 'mwWA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Province of Pennsylvania'},
#               {'#text': 'British colonial era',
#                '@href': './Colonial_history_of_the_United_States',
#                '@id': 'mwWQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Colonial history of the United States'},
#               {'#text': "nation's founding fathers",
#                '@href': './Founding_Fathers_of_the_United_States',
#                '@id': 'mwXg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Founding Fathers of the United States'},
#               {'#text': 'Revolutionary War',
#                '@href': './American_Revolutionary_War',
#                '@id': 'mwXw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'American Revolutionary War'},
#               {'#text': 'First Continental Congress',
#                '@href': './First_Continental_Congress',
#                '@id': 'mwYA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'First Continental Congress'},
#               {'#text': 'Liberty Bell',
#                '@href': './Liberty_Bell#Early_days_(1754–1777)',
#                '@id': 'mwYQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Liberty Bell'},
#               {'#text': 'Second Continental Congress',
#                '@href': './Second_Continental_Congress',
#                '@id': 'mwYg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Second Continental Congress'},
#               {'#text': 'Declaration of Independence',
#                '@href': './United_States_Declaration_of_Independence',
#                '@id': 'mwYw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'United States Declaration of Independence'},
#               {'#text': 'Joseph Ellis',
#                '@href': './Joseph_Ellis',
#                '@id': 'mwZA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Joseph Ellis'},
#               {'#text': 'Battle of Germantown',
#                '@href': './Battle_of_Germantown',
#                '@id': 'mwZw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Battle of Germantown'},
#               {'#text': 'siege of Fort Mifflin',
#                '@href': './Siege_of_Fort_Mifflin',
#                '@id': 'mwaA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Siege of Fort Mifflin'},
#               {'#text': 'U.S. Constitution',
#                '@href': './Constitution_of_the_United_States',
#                '@id': 'mwaQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Constitution of the United States'},
#               {'#text': 'Philadelphia Convention',
#                '@href': './Constitutional_Convention_(United_States)',
#                '@id': 'mwag',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Constitutional Convention (United States)'},
#               {'#text': 'Washington, D.C.',
#                '@href': './Washington,_D.C.',
#                '@id': 'mwaw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Washington, D.C.'}],
#         'sup': [{'@about': '#mwt126',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{"name":"weigley"}}',
#                  '@id': 'cite_ref-weigley_5-1',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-weigley-5',
#                        '@id': 'mwWg',
#                        '@style': 'counter-reset: mw-Ref 5;',
#                        'span': {'#text': '[5]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwWw'}}},
#                 {'@about': '#mwt130',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-17"}}',
#                  '@id': 'cite_ref-17',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-17',
#                        '@id': 'mwXA',
#                        '@style': 'counter-reset: mw-Ref 17;',
#                        'span': {'#text': '[17]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwXQ'}}},
#                 {'@about': '#mwt134',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{"name":"American '
#                              'Creation"},"body":{"id":"mw-reference-text-cite_note-American_Creation-18"}}',
#                  '@id': 'cite_ref-American_Creation_18-0',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-American_Creation-18',
#                        '@id': 'mwZQ',
#                        '@style': 'counter-reset: mw-Ref 18;',
#                        'span': {'#text': '[18]',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwZg'}}}]},
#        {'#text': "With , Philadelphia is one of the nation's leading centers "
#                  'for higher education and . , the Philadelphia metropolitan '
#                  "area was the state's largest and  with a  of US$444.1 "
#                  'billion. The city is home to five  corporate headquarters as '
#                  'of 2022. The , which includes several globally renowned '
#                  'commercial , is expanding, primarily with new residential  . '
#                  'Philadelphia and the Delaware Valley are a  hub. As of 2023, '
#                  'metropolitan Philadelphia ranks among the top five U.S.  '
#                  "centers, facilitated by its proximity to New York City's  "
#                  "and . The , owned by  since 2008, is the nation's oldest "
#                  "stock exchange and a global leader in  trading. , the city's "
#                  "primary rail station, is the  in the nation, and the city's  "
#                  'and  infrastructure, including , the rapidly-growing ,  '
#                  'infrastructure, roadway traffic capacity, and  storage '
#                  'space, are all expanding. A migration pattern has been '
#                  'established from New York City to Philadelphia by residents '
#                  'opting for a large city with relative proximity and a lower '
#                  '.',
#         '@id': 'mwbA',
#         'a': [{'#text': '18 four-year universities and colleges',
#                '@href': './List_of_colleges_and_universities_in_Philadelphia',
#                '@id': 'mwbQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of colleges and universities in Philadelphia'},
#               {'#text': 'academic research',
#                '@class': 'mw-redirect',
#                '@href': './Academic_research',
#                '@id': 'mwbg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Academic research'},
#               {'#text': "nation's ninth-largest metropolitan economy",
#                '@href': './List_of_U.S._metropolitan_areas_by_GDP',
#                '@id': 'mwdQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of U.S. metropolitan areas by GDP'},
#               {'#text': 'gross metropolitan product',
#                '@href': './Gross_metropolitan_product',
#                '@id': 'mwdg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Gross metropolitan product'},
#               {'#text': 'Fortune 500',
#                '@href': './Fortune_500',
#                '@id': 'mwdw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Fortune 500'},
#               {'#text': 'Philadelphia skyline',
#                '@href': './List_of_tallest_buildings_in_Philadelphia',
#                '@id': 'mweg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of tallest buildings in Philadelphia'},
#               {'#text': 'skyscrapers',
#                '@href': './List_of_tallest_buildings_in_Philadelphia',
#                '@id': 'mwew',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of tallest buildings in Philadelphia'},
#               {'#text': 'high-rise',
#                '@href': './Tower_block',
#                '@id': 'mwfA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Tower block'},
#               {'#text': 'condominiums',
#                '@class': 'mw-redirect',
#                '@href': './Condominium_(living_space)',
#                '@id': 'mwfQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Condominium (living space)'},
#               {'#text': 'biotechnology',
#                '@href': './Biotechnology',
#                '@id': 'mwgA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Biotechnology'},
#               {'#text': 'venture capital',
#                '@href': './Venture_capital',
#                '@id': 'mwgw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Venture capital'},
#               {'#text': 'entrepreneurial',
#                '@href': './Entrepreneurship',
#                '@id': 'mwhA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Entrepreneurship'},
#               {'#text': 'financial ecosystems',
#                '@href': './Wall_Street',
#                '@id': 'mwhQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Wall Street'},
#               {'#text': 'Philadelphia Stock Exchange',
#                '@href': './Philadelphia_Stock_Exchange',
#                '@id': 'mwiA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Philadelphia Stock Exchange'},
#               {'#text': 'Nasdaq',
#                '@href': './Nasdaq',
#                '@id': 'mwiQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Nasdaq'},
#               {'#text': 'options',
#                '@href': './Option_(finance)',
#                '@id': 'mwig',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Option (finance)'},
#               {'#text': '30th Street Station',
#                '@href': './30th_Street_Station',
#                '@id': 'mwjQ',
#                '@rel': 'mw:WikiLink',
#                '@title': '30th Street Station'},
#               {'#text': 'third-busiest Amtrak hub',
#                '@href': './List_of_busiest_Amtrak_stations',
#                '@id': 'mwjg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of busiest Amtrak stations'},
#               {'#text': 'multimodal transport',
#                '@href': './Multimodal_transport',
#                '@id': 'mwjw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Multimodal transport'},
#               {'#text': 'logistics',
#                '@href': './Logistics',
#                '@id': 'mwkA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Logistics'},
#               {'#text': 'Philadelphia International Airport',
#                '@href': './Philadelphia_International_Airport',
#                '@id': 'mwkQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Philadelphia International Airport'},
#               {'#text': 'PhilaPort seaport',
#                '@href': './Port_of_Philadelphia',
#                '@id': 'mwkg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Port of Philadelphia'},
#               {'#text': 'freight rail',
#                '@href': './Rail_freight_transport',
#                '@id': 'mwlQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Rail freight transport'},
#               {'#text': 'warehouse',
#                '@href': './Warehouse',
#                '@id': 'mwlg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Warehouse'},
#               {'#text': 'cost of living',
#                '@href': './Cost_of_living',
#                '@id': 'mwlw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Cost of living'}],
#         'link': [{'@about': '#mwt145',
#                   '@href': './Category:Articles_containing_potentially_dated_statements_from_2018',
#                   '@rel': 'mw:PageProp/Category'},
#                  {'@about': '#mwt145',
#                   '@href': './Category:All_articles_containing_potentially_dated_statements',
#                   '@id': 'mwdA',
#                   '@rel': 'mw:PageProp/Category'}],
#         'span': [{'#text': 'As of 2018',
#                   '@about': '#mwt145',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"As '
#                               'of","href":"./Template:As_of"},"params":{"1":{"wt":"2018"}},"i":0}}]}',
#                   '@id': 'mwcw',
# ...
#                                            '@title': 'List of North American '
#                                                      'cities by population'},
#                                           {'#text': '6th',
#                                            '@href': './List_of_United_States_cities_by_population',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'List of United States '
#                                                      'cities by population'},
#                                           {'#text': '1st',
#                                            '@class': 'mw-redirect',
#                                            '@href': './List_of_cities_and_boroughs_in_Pennsylvania_by_population',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'List of cities and '
#                                                      'boroughs in Pennsylvania '
#                                                      'by population'}],
#                                     'br': [None, None]},
#                              'th': {'#text': '•Rank',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'span': [{'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '11,936.92/sqmi (4,608.86/km)',
#                                     '@class': 'infobox-data',
#                                     'span': {'@typeof': 'mw:Entity'},
#                                     'sup': '2'},
#                              'th': {'#text': '•Density',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'span': [{'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '5,696,125 (US: )',
#                                     '@class': 'infobox-data',
#                                     'a': {'#text': '7th',
#                                           '@href': './List_of_United_States_urban_areas',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'List of United States '
#                                                     'urban areas'}},
#                              'th': {'#text': '•',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Urban',
#                                           '@href': './Urban_area',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Urban area'},
#                                     'div': {'@class': 'ib-settlement-fn',
#                                             'sup': {'@about': '#mwt89',
#                                                     '@class': 'mw-ref '
#                                                               'reference',
#                                                     '@data-mw': '{"name":"ref","attrs":{"name":"urban '
#                                                                 'area"},"body":{"id":"mw-reference-text-cite_note-urban_area-9"}}',
#                                                     '@id': 'cite_ref-urban_area_9-0',
#                                                     '@rel': 'dc:references',
#                                                     '@typeof': 'mw:Extension/ref',
#                                                     'a': {'@href': './Philadelphia#cite_note-urban_area-9',
#                                                           '@id': 'mwJg',
#                                                           '@style': 'counter-reset: '
#                                                                     'mw-Ref 9;',
#                                                           'span': {'#text': '[9]',
#                                                                    '@class': 'mw-reflink-text',
#                                                                    '@id': 'mwJw'}}}},
#                                     'span': [{'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '3,000.8/sqmi (1,158.6/km)',
#                                     '@class': 'infobox-data',
#                                     'span': {'@typeof': 'mw:Entity'},
#                                     'sup': '2'},
#                              'th': {'#text': '•Urbandensity',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'span': [{'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '6,245,051 (US: )',
#                                     '@class': 'infobox-data',
#                                     'a': {'#text': '7th',
#                                           '@class': 'mw-redirect',
#                                           '@href': './List_of_metropolitan_statistical_areas',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'List of metropolitan '
#                                                     'statistical areas'}},
#                              'th': {'#text': '•',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Metro',
#                                           '@href': './Metropolitan_area',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Metropolitan area'},
#                                     'div': {'@class': 'ib-settlement-fn',
#                                             'sup': {'@about': '#mwt93',
#                                                     '@class': 'mw-ref '
#                                                               'reference',
#                                                     '@data-mw': '{"name":"ref","attrs":{"name":"2020Pop"},"body":{"id":"mw-reference-text-cite_note-2020Pop-10"}}',
#                                                     '@id': 'cite_ref-2020Pop_10-0',
#                                                     '@rel': 'dc:references',
#                                                     '@typeof': 'mw:Extension/ref',
#                                                     'a': {'@href': './Philadelphia#cite_note-2020Pop-10',
#                                                           '@id': 'mwKA',
#                                                           '@style': 'counter-reset: '
#                                                                     'mw-Ref '
#                                                                     '10;',
#                                                           'span': {'#text': '[10]',
#                                                                    '@class': 'mw-reflink-text',
#                                                                    '@id': 'mwKQ'}}}},
#                                     'span': [{'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'#text': 'Philadelphian',
#                                     '@class': 'infobox-data'},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Demonym',
#                                           '@href': './Demonym',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Demonym'}}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'#text': '()',
#                                     '@class': 'infobox-data',
#                                     'a': [{'#text': 'UTC−5',
#                                            '@class': 'mw-redirect',
#                                            '@href': './UTC−5',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'UTC−5'},
#                                           {'#text': 'EST',
#                                            '@class': 'mw-redirect',
#                                            '@href': './North_American_Eastern_Time_Zone',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'North American Eastern '
#                                                      'Time Zone'}]},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Time zone',
#                                           '@href': './Time_zone',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Time zone'}}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '()',
#                                     '@class': 'infobox-data',
#                                     'a': [{'#text': 'UTC−4',
#                                            '@class': 'mw-redirect',
#                                            '@href': './UTC−4',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'UTC−4'},
#                                           {'#text': 'EDT',
#                                            '@class': 'mw-redirect',
#                                            '@href': './Eastern_Daylight_Time',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'Eastern Daylight Time'}]},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'span': {'#text': '•Summer ()',
#                                              '@class': 'nowrap',
#                                              'a': {'#text': 'DST',
#                                                    '@href': './Daylight_saving_time',
#                                                    '@rel': 'mw:WikiLink',
#                                                    '@title': 'Daylight saving '
#                                                              'time'},
#                                              'span': [{'@typeof': 'mw:Entity'},
#                                                       {'@typeof': 'mw:Entity'}]}}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'@class': 'infobox-data adr',
#                                     'div': {'#text': '19092–19093, 19099, '
#                                                      '191xx',
#                                             '@class': 'postal-code'}},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'ZIP Codes',
#                                           '@href': './ZIP_Code',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'ZIP Code'}}},
#                             {'@class': 'mergedrow',
#                              'td': {'@class': 'infobox-data',
#                                     'a': {'#text': '215, 267, 445',
#                                           '@href': './Area_codes_215,_267,_and_445',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Area codes 215, 267, and '
#                                                     '445'}},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Area codes',
#                                           '@href': './Telephone_numbering_plan',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Telephone numbering '
#                                                     'plan'}}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'#text': '42-60000',
#                                     '@class': 'infobox-data'},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'FIPS code',
#                                           '@href': './Federal_Information_Processing_Standards',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Federal Information '
#                                                     'Processing Standards'}}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '1215531',
#                                     '@class': 'infobox-data',
#                                     'sup': {'@about': '#mwt97',
#                                             '@class': 'mw-ref reference',
#                                             '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-11"}}',
#                                             '@id': 'cite_ref-11',
#                                             '@rel': 'dc:references',
#                                             '@typeof': 'mw:Extension/ref',
#                                             'a': {'@href': './Philadelphia#cite_note-11',
#                                                   '@id': 'mwKg',
#                                                   '@style': 'counter-reset: '
#                                                             'mw-Ref 11;',
#                                                   'span': {'#text': '[11]',
#                                                            '@class': 'mw-reflink-text',
#                                                            '@id': 'mwKw'}}}},
#                              'th': {'#text': 'feature ID',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'GNIS',
#                                           '@href': './Geographic_Names_Information_System',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Geographic Names '
#                                                     'Information System'}}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'@class': 'infobox-data',
#                                     'a': {'#text': 'www.phila.gov',
#                                           '@class': 'external text',
#                                           '@href': 'http://www.phila.gov/',
#                                           '@rel': 'mw:ExtLink nofollow'}},
#                              'th': {'#text': 'Website',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row'}}]}}}

# %% [markdown]
# ## 3.2 API authentication
# The GitHub and SEPTA examples we've looked at so far are APIs that don't require any authentication to access. Anyone can send a request to these APIs and receive a response. There are, however, quite a few APIs that require the user to have some authentication. This authentication usually takes the form of an access token that needs to be obtained from the API provider before making requests.
#
# ### 3.2.1 Example: Sportradar
# As an example, we'll take a look at one of the [Sportradar APIs](https://developer.sportradar.com). Sportradar has APIs for a number of different sports.
#
# In order to use any of their APIs, Sportradar requires you to open a developer account and register an app. Only then you are granted an access token or "API key", which you must plug in to any requests you make.
#
# The steps to obtain an API key from Sportradar are:
# 1. Sign up as a developer [here](https://developer.sportradar.com/member/register)
# 2. Sign in to your account and go your [account page](https://developer.sportradar.com/member/my-account)
# 3. Go to your [applications page](https://developer.sportradar.com/apps/myapps)
# 4. Register a new application and select the API keys you need
#
# We'll use the Sportradar Soccer API to obtain the match schedule for an English soccer team, Manchester City.
#
# First, we'll construct the request address using the API key.

# %%
soccer_key = "xy5kwnrtm4mm6vru9w9rr7r6"

# %%
# format: "https://api.sportradar.us/soccer-xt3/eu/en/teams/TEAM_ID/schedule.json?api_key=API_KEY"
address = "https://api.sportradar.com/soccer-advanced-analytics/trial/v1/en/competitors/sr:competitor:44/schedules.json?api_key=" + soccer_key

# %%
resp = requests.get(address)

# %%
result = resp.json()

# %%
pprint(result)
# Out:
# {'generated_at': '2023-10-24T00:24:32+00:00',
#  'schedules': [{'sport_event': {'channels': [{'country': 'Italy',
#                                               'country_code': 'ITA',
#                                               'name': 'Sky Sport Uno HD - Hot '
#                                                       'Bird 1/2/3/4/6 (13.0E)',
#                                               'url': 'https://guidatv.sky.it/sport-e-calcio?vista=griglia'},
#                                              {'country': 'Romania',
#                                               'country_code': 'ROU',
#                                               'name': 'Digi Sport 1 RO - Thor '
#                                                       '2/3 (1.0W)',
#                                               'url': 'http://www.digisport.ro/Program/'},
#                                              {'country': 'Great Britain',
#                                               'country_code': 'GBR',
#                                               'name': 'TNT Sports 1 - Eurobird '
#                                                       '1 / Astra 2A/2B/2D '
#                                                       '(28.2E)',
#                                               'url': 'https://www.bt.com/sport/watch/tv-guide'},
#                                              {'country': 'Hungary',
#                                               'country_code': 'HUN',
#                                               'name': 'Spiler 1 TV - Thor 2/3 '
#                                                       '(1.0W)',
#                                               'url': 'http://spilertv.hu/musorujsag/'},
#                                              {'country': 'Romania',
#                                               'country_code': 'ROU',
#                                               'name': 'Spiler 1 TV - Thor 2/3 '
#                                                       '(1.0W)',
#                                               'url': 'http://spilertv.hu/musorujsag/'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'Universo'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'USA Network',
#                                               'url': 'https://www.usanetwork.com/'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'Fubo TV'},
#                                              {'country': 'France',
#                                               'country_code': 'FRA',
#                                               'name': 'CANAL+ Foot FR - Astra '
#                                                       '1C-1H / 2C (19.2E)',
#                                               'url': 'https://www.canalplus.com/programme-tv/'},
#                                              {'country': 'Greece',
#                                               'country_code': 'GRC',
#                                               'name': 'Novasports PL HD - Hot '
#                                                       'Bird 1/2/3/4/6 '
#                                                       '(13.0E)'}],
#                                 'competitors': [{'abbreviation': 'LIV',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:44',
#                                                  'name': 'Liverpool FC',
#                                                  'qualifier': 'home'},
#                                                 {'abbreviation': 'EVE',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:48',
#                                                  'name': 'Everton FC',
#                                                  'qualifier': 'away'}],
#                                 'coverage': {'sport_event_properties': {'advanced_data': 'live',
#                                                                         'ballspotting': True,
#                                                                         'basic_play_by_play': True,
#                                                                         'basic_player_stats': True,
#                                                                         'basic_team_stats': True,
#                                                                         'commentary': True,
#                                                                         'deeper_play_by_play': True,
#                                                                         'deeper_player_stats': True,
#                                                                         'deeper_team_stats': True,
#                                                                         'fun_facts': True,
#                                                                         'game_clock': True,
#                                                                         'goal_scorers': True,
#                                                                         'lineups': True,
#                                                                         'lineups_availability': 'pre',
#                                                                         'scores': 'live',
#                                                                         'venue': True},
#                                              'type': 'sport_event'},
#                                 'id': 'sr:sport_event:41763007',
#                                 'sport_event_conditions': {'ground': {'neutral': False},
#                                                            'lineups': {'confirmed': True},
#                                                            'referees': [{'country_code': 'ENG',
#                                                                          'id': 'sr:referee:81627',
#                                                                          'name': 'Pawson, '
#                                                                                  'Craig',
#                                                                          'nationality': 'England',
#                                                                          'type': 'main_referee'},
#                                                                         {'country_code': 'ENG',
#                                                                          'id': 'sr:referee:107841',
#                                                                          'name': 'Perry, '
#                                                                                  'Marc',
#                                                                          'nationality': 'England',
#                                                                          'type': 'first_assistant_referee'},
#                                                                         {'country_code': 'ENG',
#                                                                          'id': 'sr:referee:2208914',
#                                                                          'name': 'Smith, '
#                                                                                  'Wade',
#                                                                          'nationality': 'England',
#                                                                          'type': 'second_assistant_referee'},
#                                                                         {'country_code': 'ENG',
#                                                                          'id': 'sr:referee:248523',
#                                                                          'name': 'Bramall, '
#                                                                                  'Thomas',
#                                                                          'nationality': 'England',
#                                                                          'type': 'fourth_official'},
#                                                                         {'country_code': 'ENG',
#                                                                          'id': 'sr:referee:92026',
#                                                                          'name': 'Coote, '
#                                                                                  'David',
#                                                                          'nationality': 'England',
#                                                                          'type': 'video_assistant_referee'}]},
#                                 'sport_event_context': {'category': {'country_code': 'ENG',
#                                                                      'id': 'sr:category:1',
#                                                                      'name': 'England'},
#                                                         'competition': {'gender': 'men',
#                                                                         'id': 'sr:competition:17',
#                                                                         'name': 'Premier '
#                                                                                 'League'},
#                                                         'groups': [{'id': 'sr:league:74627',
#                                                                     'name': 'Premier '
#                                                                             'League '
#                                                                             '23/24'}],
#                                                         'round': {'number': 9},
#                                                         'season': {'competition_id': 'sr:competition:17',
#                                                                    'end_date': '2024-05-19',
#                                                                    'id': 'sr:season:105353',
#                                                                    'name': 'Premier '
#                                                                            'League '
#                                                                            '23/24',
#                                                                    'start_date': '2023-08-11',
#                                                                    'year': '23/24'},
#                                                         'sport': {'id': 'sr:sport:1',
#                                                                   'name': 'Soccer'},
#                                                         'stage': {'end_date': '2024-05-19',
#                                                                   'order': 1,
#                                                                   'phase': 'regular '
#                                                                            'season',
#                                                                   'start_date': '2023-08-11',
#                                                                   'type': 'league',
#                                                                   'year': '23/24'}},
#                                 'start_time': '2023-10-21T11:30:00+00:00',
#                                 'start_time_confirmed': True,
#                                 'venue': {'capacity': 54074,
#                                           'city_name': 'Liverpool',
#                                           'country_code': 'ENG',
#                                           'country_name': 'England',
#                                           'id': 'sr:venue:579',
#                                           'map_coordinates': '53.430622,-2.960919',
#                                           'name': 'Anfield',
#                                           'timezone': 'Europe/London'}},
#                 'sport_event_status': {'away_score': 0,
#                                        'ball_locations': [{'order': 4,
#                                                            'qualifier': 'home',
#                                                            'x': 46,
#                                                            'y': 19},
#                                                           {'order': 3,
#                                                            'qualifier': 'home',
#                                                            'x': 43,
#                                                            'y': 16},
#                                                           {'order': 2,
#                                                            'qualifier': 'home',
#                                                            'x': 19,
#                                                            'y': 14},
#                                                           {'order': 1,
#                                                            'qualifier': 'home',
#                                                            'x': 8,
#                                                            'y': 50}],
#                                        'home_score': 2,
#                                        'match_situation': {'qualifier': 'home',
#                                                            'status': 'safe',
#                                                            'updated_at': '2023-10-21T13:29:23+00:00'},
#                                        'match_status': 'ended',
#                                        'period_scores': [{'away_score': 0,
#                                                           'home_score': 0,
#                                                           'number': 1,
#                                                           'type': 'regular_period'},
#                                                          {'away_score': 0,
#                                                           'home_score': 2,
#                                                           'number': 2,
#                                                           'type': 'regular_period'}],
#                                        'status': 'closed',
#                                        'winner_id': 'sr:competitor:44'}},
#                {'sport_event': {'channels': [{'country': 'Great Britain',
#                                               'country_code': 'GBR',
#                                               'name': 'Sky Sports Main Event '
#                                                       'HD - Astra 2A/2B/2D '
#                                                       '(28.2E)',
#                                               'url': 'http://www.skysports.com/watch/sport-on-sky'},
#                                              {'country': 'Romania',
#                                               'country_code': 'ROU',
#                                               'name': 'Digi Sport 3 RO - Thor '
#                                                       '2/3 (1.0W)',
#                                               'url': 'http://www.digisport.ro/Program/'},
#                                              {'country': 'Turkey',
#                                               'country_code': 'TUR',
#                                               'name': 'Bein Sports HD 3 TR - '
#                                                       'Eutelsat W3A (7.0E)',
#                                               'url': 'http://tr.beinsports.com/yayin-akisi/beinsports-3'},
#                                              {'country': 'Great Britain',
#                                               'country_code': 'GBR',
#                                               'name': 'Sky Sports PL HD - '
#                                                       'Astra 2A/2B/2D (28.2E)',
#                                               'url': 'http://www.skysports.com/watch/sport-on-sky'},
#                                              {'country': 'Greece',
#                                               'country_code': 'GRC',
#                                               'name': 'Novasports Prime HD - '
#                                                       'Hot Bird 1/2/3/4/6 '
#                                                       '(13.0E)',
#                                               'url': 'https://www.cyta.com.cy/tv-live-sports-events/en'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'Peacock Premium'},
#                                              {'country': 'France',
#                                               'country_code': 'FRA',
#                                               'name': 'CANAL+ SPORT 360 FR - '
#                                                       'Astra 1C-1H / 2C '
#                                                       '(19.2E)',
#                                               'url': 'https://www.canalplus.com/programme-tv/'}],
#                                 'competitors': [{'abbreviation': 'BRI',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:30',
#                                                  'name': 'Brighton & Hove '
#                                                          'Albion',
#                                                  'qualifier': 'home'},
#                                                 {'abbreviation': 'LIV',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:44',
#                                                  'name': 'Liverpool FC',
#                                                  'qualifier': 'away'}],
#                                 'coverage': {'sport_event_properties': {'advanced_data': 'live',
#                                                                         'ballspotting': True,
#                                                                         'basic_play_by_play': True,
#                                                                         'basic_player_stats': True,
#                                                                         'basic_team_stats': True,
#                                                                         'commentary': True,
#                                                                         'deeper_play_by_play': True,
#                                                                         'deeper_player_stats': True,
#                                                                         'deeper_team_stats': True,
#                                                                         'fun_facts': True,
#                                                                         'game_clock': True,
#                                                                         'goal_scorers': True,
#                                                                         'lineups': True,
#                                                                         'lineups_availability': 'pre',
#                                                                         'scores': 'live',
#                                                                         'venue': True},
#                                              'type': 'sport_event'},
#                                 'id': 'sr:sport_event:41762981',
#                                 'sport_event_conditions': {'attendance': {'count': 31752},
#                                                            'ground': {'neutral': False},
#                                                            'lineups': {'confirmed': True}},
#                                 'sport_event_context': {'category': {'country_code': 'ENG',
#                                                                      'id': 'sr:category:1',
#                                                                      'name': 'England'},
#                                                         'competition': {'gender': 'men',
#                                                                         'id': 'sr:competition:17',
#                                                                         'name': 'Premier '
#                                                                                 'League'},
#                                                         'groups': [{'id': 'sr:league:74627',
#                                                                     'name': 'Premier '
#                                                                             'League '
#                                                                             '23/24'}],
#                                                         'round': {'number': 8},
#                                                         'season': {'competition_id': 'sr:competition:17',
#                                                                    'end_date': '2024-05-19',
#                                                                    'id': 'sr:season:105353',
#                                                                    'name': 'Premier '
#                                                                            'League '
#                                                                            '23/24',
#                                                                    'start_date': '2023-08-11',
#                                                                    'year': '23/24'},
#                                                         'sport': {'id': 'sr:sport:1',
#                                                                   'name': 'Soccer'},
#                                                         'stage': {'end_date': '2024-05-19',
#                                                                   'order': 1,
#                                                                   'phase': 'regular '
#                                                                            'season',
#                                                                   'start_date': '2023-08-11',
#                                                                   'type': 'league',
#                                                                   'year': '23/24'}},
#                                 'start_time': '2023-10-08T13:00:00+00:00',
#                                 'start_time_confirmed': True,
#                                 'venue': {'capacity': 30750,
#                                           'city_name': 'Falmer',
#                                           'country_code': 'ENG',
#                                           'country_name': 'England',
#                                           'id': 'sr:venue:2443',
#                                           'map_coordinates': '50.861822,-0.083278',
#                                           'name': 'American Express Community '
#                                                   'Stadium',
#                                           'timezone': 'Europe/London'}},
#                 'sport_event_status': {'away_score': 2,
#                                        'home_score': 2,
#                                        'match_status': 'ended',
#                                        'match_tie': True,
#                                        'period_scores': [{'away_score': 2,
#                                                           'home_score': 1,
#                                                           'number': 1,
#                                                           'type': 'regular_period'},
#                                                          {'away_score': 0,
#                                                           'home_score': 1,
#                                                           'number': 2,
#                                                           'type': 'regular_period'}],
#                                        'status': 'closed'}},
#                {'sport_event': {'channels': [{'country': 'Great Britain',
#                                               'country_code': 'GBR',
#                                               'name': 'Sky Sports Main Event '
#                                                       'HD - Astra 2A/2B/2D '
#                                                       '(28.2E)',
#                                               'url': 'http://www.skysports.com/watch/sport-on-sky'},
#                                              {'country': 'Italy',
#                                               'country_code': 'ITA',
#                                               'name': 'Sky Sport Uno HD - Hot '
#                                                       'Bird 1/2/3/4/6 (13.0E)',
#                                               'url': 'https://guidatv.sky.it/sport-e-calcio?vista=griglia'},
#                                              {'country': 'Romania',
#                                               'country_code': 'ROU',
#                                               'name': 'Digi Sport 1 RO - Thor '
#                                                       '2/3 (1.0W)',
#                                               'url': 'http://www.digisport.ro/Program/'},
#                                              {'country': 'France',
#                                               'country_code': 'FRA',
#                                               'name': 'CANAL+ FR - Astra 1C-1H '
#                                                       '/ 2C (19.2E)',
#                                               'url': 'https://www.canalplus.com/programme-tv/'},
#                                              {'country': 'Great Britain',
#                                               'country_code': 'GBR',
#                                               'name': 'Sky Sports PL HD - '
#                                                       'Astra 2A/2B/2D (28.2E)',
#                                               'url': 'http://www.skysports.com/watch/sport-on-sky'},
#                                              {'country': 'Sweden',
#                                               'country_code': 'SWE',
#                                               'name': 'V Sport Premium HD - '
#                                                       'Thor 2/3 (1.0W)',
#                                               'url': 'https://www.allente.se/tv-guide/'},
#                                              {'country': 'Hungary',
#                                               'country_code': 'HUN',
#                                               'name': 'Spiler 1 TV - Thor 2/3 '
#                                                       '(1.0W)',
#                                               'url': 'http://spilertv.hu/musorujsag/'},
#                                              {'country': 'Romania',
#                                               'country_code': 'ROU',
#                                               'name': 'Spiler 1 TV - Thor 2/3 '
#                                                       '(1.0W)',
#                                               'url': 'http://spilertv.hu/musorujsag/'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'Universo'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'USA Network',
#                                               'url': 'https://www.usanetwork.com/'},
#                                              {'country': 'Greece',
#                                               'country_code': 'GRC',
#                                               'name': 'Novasports PL HD - Hot '
#                                                       'Bird 1/2/3/4/6 '
#                                                       '(13.0E)'}],
#                                 'competitors': [{'abbreviation': 'TOT',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:33',
#                                                  'name': 'Tottenham Hotspur',
#                                                  'qualifier': 'home'},
#                                                 {'abbreviation': 'LIV',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:44',
#                                                  'name': 'Liverpool FC',
#                                                  'qualifier': 'away'}],
#                                 'coverage': {'sport_event_properties': {'advanced_data': 'live',
#                                                                         'ballspotting': True,
#                                                                         'basic_play_by_play': True,
#                                                                         'basic_player_stats': True,
#                                                                         'basic_team_stats': True,
#                                                                         'commentary': True,
#                                                                         'deeper_play_by_play': True,
#                                                                         'deeper_player_stats': True,
#                                                                         'deeper_team_stats': True,
#                                                                         'fun_facts': True,
#                                                                         'game_clock': True,
#                                                                         'goal_scorers': True,
#                                                                         'lineups': True,
#                                                                         'lineups_availability': 'pre',
#                                                                         'scores': 'live',
#                                                                         'venue': True},
#                                              'type': 'sport_event'},
#                                 'id': 'sr:sport_event:41762973',
#                                 'sport_event_conditions': {'attendance': {'count': 62001},
#                                                            'ground': {'neutral': False},
#                                                            'lineups': {'confirmed': True}},
#                                 'sport_event_context': {'category': {'country_code': 'ENG',
#                                                                      'id': 'sr:category:1',
#                                                                      'name': 'England'},
#                                                         'competition': {'gender': 'men',
#                                                                         'id': 'sr:competition:17',
#                                                                         'name': 'Premier '
#                                                                                 'League'},
#                                                         'groups': [{'id': 'sr:league:74627',
#                                                                     'name': 'Premier '
#                                                                             'League '
#                                                                             '23/24'}],
#                                                         'round': {'number': 7},
#                                                         'season': {'competition_id': 'sr:competition:17',
#                                                                    'end_date': '2024-05-19',
#                                                                    'id': 'sr:season:105353',
#                                                                    'name': 'Premier '
#                                                                            'League '
#                                                                            '23/24',
#                                                                    'start_date': '2023-08-11',
#                                                                    'year': '23/24'},
#                                                         'sport': {'id': 'sr:sport:1',
#                                                                   'name': 'Soccer'},
#                                                         'stage': {'end_date': '2024-05-19',
#                                                                   'order': 1,
#                                                                   'phase': 'regular '
#                                                                            'season',
#                                                                   'start_date': '2023-08-11',
#                                                                   'type': 'league',
#                                                                   'year': '23/24'}},
#                                 'start_time': '2023-09-30T16:30:00+00:00',
#                                 'start_time_confirmed': True,
#                                 'venue': {'capacity': 60463,
#                                           'city_name': 'London',
#                                           'country_code': 'ENG',
#                                           'country_name': 'England',
#                                           'id': 'sr:venue:28762',
#                                           'map_coordinates': '51.604444, '
#                                                              '-0.066389',
#                                           'name': 'Tottenham Hotspur Stadium',
#                                           'timezone': 'Europe/London'}},
#                 'sport_event_status': {'away_score': 1,
#                                        'home_score': 2,
#                                        'match_status': 'ended',
#                                        'period_scores': [{'away_score': 1,
#                                                           'home_score': 1,
#                                                           'number': 1,
#                                                           'type': 'regular_period'},
#                                                          {'away_score': 0,
#                                                           'home_score': 1,
#                                                           'number': 2,
#                                                           'type': 'regular_period'}],
#                                        'status': 'closed',
#                                        'winner_id': 'sr:competitor:33'}},
#                {'sport_event': {'channels': [{'country': 'France',
#                                               'country_code': 'FRA',
#                                               'name': 'MultiSports 2 HD FR - '
#                                                       'Astra 1C-1H / 2C '
#                                                       '(19.2E)',
#                                               'url': 'http://television.telerama.fr/tele/chaine-tv/multisports-6,106.php?&date=2016-12-14'},
#                                              {'country': 'Greece',
#                                               'country_code': 'GRC',
#                                               'name': 'novasports2 HD - Hot '
#                                                       'Bird 1/2/3/4/6 (13.0E)',
#                                               'url': 'https://www.nova.gr/el/novaguide'},
#                                              {'country': 'Sweden',
#                                               'country_code': 'SWE',
#                                               'name': 'V Sport Football HD SE '
#                                                       '- Thor 2/3 (1.0W)',
#                                               'url': 'https://www.allente.se/tv-guide/'},
#                                              {'country': 'Romania',
#                                               'country_code': 'ROU',
#                                               'name': 'Digi Sport 2 RO - Thor '
#                                                       '2/3 (1.0W)',
#                                               'url': 'http://www.digisport.ro/Program/'},
#                                              {'country': 'Italy',
#                                               'country_code': 'ITA',
#                                               'name': 'SKY Sport 257 HD - Hot '
#                                                       'Bird 1/2/3/4/6 (13.0E)',
#                                               'url': 'https://guidatv.sky.it/sport-e-calcio?vista=griglia'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'Peacock Premium'},
#                                              {'country': 'France',
#                                               'country_code': 'FRA',
#                                               'name': 'CANAL+ Foot FR - Astra '
#                                                       '1C-1H / 2C (19.2E)',
#                                               'url': 'https://www.canalplus.com/programme-tv/'},
#                                              {'country': 'Hungary',
#                                               'country_code': 'HUN',
#                                               'name': 'MATCH4 - Thor 2/3 '
#                                                       '(1.0W)',
#                                               'url': 'https://focimagazin.hu/content/tv-m%c5%b1sor-%c3%a9l%c5%91-foci-tv-ben'},
#                                              {'country': 'Turkey',
#                                               'country_code': 'TUR',
#                                               'name': 'Bein Sports HD 5 TR - '
#                                                       'Eutelsat W3A (7.0E)',
#                                               'url': 'https://www.sporekrani.com/home/sport/futbol'}],
#                                 'competitors': [{'abbreviation': 'LIV',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:44',
#                                                  'name': 'Liverpool FC',
#                                                  'qualifier': 'home'},
#                                                 {'abbreviation': 'WHU',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:37',
#                                                  'name': 'West Ham United',
#                                                  'qualifier': 'away'}],
#                                 'coverage': {'sport_event_properties': {'advanced_data': 'live',
#                                                                         'ballspotting': True,
#                                                                         'basic_play_by_play': True,
#                                                                         'basic_player_stats': True,
#                                                                         'basic_team_stats': True,
#                                                                         'commentary': True,
#                                                                         'deeper_play_by_play': True,
#                                                                         'deeper_player_stats': True,
#                                                                         'deeper_team_stats': True,
#                                                                         'fun_facts': True,
#                                                                         'game_clock': True,
#                                                                         'goal_scorers': True,
#                                                                         'lineups': True,
#                                                                         'lineups_availability': 'pre',
#                                                                         'scores': 'live',
#                                                                         'venue': True},
#                                              'type': 'sport_event'},
#                                 'id': 'sr:sport_event:41762951',
#                                 'sport_event_conditions': {'attendance': {'count': 50136},
#                                                            'ground': {'neutral': False},
#                                                            'lineups': {'confirmed': True}},
#                                 'sport_event_context': {'category': {'country_code': 'ENG',
#                                                                      'id': 'sr:category:1',
#                                                                      'name': 'England'},
#                                                         'competition': {'gender': 'men',
#                                                                         'id': 'sr:competition:17',
#                                                                         'name': 'Premier '
#                                                                                 'League'},
#                                                         'groups': [{'id': 'sr:league:74627',
#                                                                     'name': 'Premier '
#                                                                             'League '
#                                                                             '23/24'}],
#                                                         'round': {'number': 6},
#                                                         'season': {'competition_id': 'sr:competition:17',
#                                                                    'end_date': '2024-05-19',
#                                                                    'id': 'sr:season:105353',
#                                                                    'name': 'Premier '
#                                                                            'League '
#                                                                            '23/24',
#                                                                    'start_date': '2023-08-11',
#                                                                    'year': '23/24'},
#                                                         'sport': {'id': 'sr:sport:1',
#                                                                   'name': 'Soccer'},
#                                                         'stage': {'end_date': '2024-05-19',
#                                                                   'order': 1,
#                                                                   'phase': 'regular '
#                                                                            'season',
#                                                                   'start_date': '2023-08-11',
#                                                                   'type': 'league',
#                                                                   'year': '23/24'}},
#                                 'start_time': '2023-09-24T13:00:00+00:00',
#                                 'start_time_confirmed': True,
#                                 'venue': {'capacity': 54074,
#                                           'city_name': 'Liverpool',
#                                           'country_code': 'ENG',
#                                           'country_name': 'England',
#                                           'id': 'sr:venue:579',
#                                           'map_coordinates': '53.430622,-2.960919',
#                                           'name': 'Anfield',
#                                           'timezone': 'Europe/London'}},
#                 'sport_event_status': {'away_score': 1,
#                                        'home_score': 3,
#                                        'match_status': 'ended',
#                                        'period_scores': [{'away_score': 1,
#                                                           'home_score': 1,
#                                                           'number': 1,
#                                                           'type': 'regular_period'},
#                                                          {'away_score': 0,
#                                                           'home_score': 2,
#                                                           'number': 2,
#                                                           'type': 'regular_period'}],
#                                        'status': 'closed',
#                                        'winner_id': 'sr:competitor:44'}},
#                {'sport_event': {'channels': [{'country': 'Italy',
#                                               'country_code': 'ITA',
#                                               'name': 'SKY Sport 253 HD - Hot '
#                                                       'Bird 1/2/3/4/6 (13.0E)',
#                                               'url': 'https://guidatv.sky.it/sport-e-calcio?vista=griglia'},
#                                              {'country': 'Turkey',
#                                               'country_code': 'TUR',
#                                               'name': 'Bein Sports HD 3 TR - '
#                                                       'Eutelsat W3A (7.0E)',
#                                               'url': 'http://tr.beinsports.com/yayin-akisi/beinsports-3'},
#                                              {'country': 'Romania',
#                                               'country_code': 'ROU',
#                                               'name': 'Digi Sport 1 RO - Thor '
#                                                       '2/3 (1.0W)',
#                                               'url': 'http://www.digisport.ro/Program/'},
#                                              {'country': 'Great Britain',
#                                               'country_code': 'GBR',
# ...
#                                                                         'id': 'sr:competition:17',
#                                                                         'name': 'Premier '
#                                                                                 'League'},
#                                                         'groups': [{'id': 'sr:league:74627',
#                                                                     'name': 'Premier '
#                                                                             'League '
#                                                                             '23/24'}],
#                                                         'round': {'number': 12},
#                                                         'season': {'competition_id': 'sr:competition:17',
#                                                                    'end_date': '2024-05-19',
#                                                                    'id': 'sr:season:105353',
#                                                                    'name': 'Premier '
#                                                                            'League '
#                                                                            '23/24',
#                                                                    'start_date': '2023-08-11',
#                                                                    'year': '23/24'},
#                                                         'sport': {'id': 'sr:sport:1',
#                                                                   'name': 'Soccer'},
#                                                         'stage': {'end_date': '2024-05-19',
#                                                                   'order': 1,
#                                                                   'phase': 'regular '
#                                                                            'season',
#                                                                   'start_date': '2023-08-11',
#                                                                   'type': 'league',
#                                                                   'year': '23/24'}},
#                                 'start_time': '2023-11-12T14:00:00+00:00',
#                                 'start_time_confirmed': True,
#                                 'venue': {'capacity': 54074,
#                                           'city_name': 'Liverpool',
#                                           'country_code': 'ENG',
#                                           'country_name': 'England',
#                                           'id': 'sr:venue:579',
#                                           'map_coordinates': '53.430622,-2.960919',
#                                           'name': 'Anfield',
#                                           'timezone': 'Europe/London'}},
#                 'sport_event_status': {'match_status': 'not_started',
#                                        'status': 'not_started'}},
#                {'sport_event': {'competitors': [{'abbreviation': 'LUT',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:72',
#                                                  'name': 'Luton Town',
#                                                  'qualifier': 'home'},
#                                                 {'abbreviation': 'LIV',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:44',
#                                                  'name': 'Liverpool FC',
#                                                  'qualifier': 'away'}],
#                                 'coverage': {'sport_event_properties': {'advanced_data': 'live',
#                                                                         'ballspotting': True,
#                                                                         'basic_play_by_play': True,
#                                                                         'basic_player_stats': True,
#                                                                         'basic_team_stats': True,
#                                                                         'commentary': True,
#                                                                         'deeper_play_by_play': True,
#                                                                         'deeper_player_stats': True,
#                                                                         'deeper_team_stats': True,
#                                                                         'fun_facts': True,
#                                                                         'game_clock': True,
#                                                                         'goal_scorers': True,
#                                                                         'lineups': True,
#                                                                         'lineups_availability': 'pre',
#                                                                         'scores': 'live',
#                                                                         'venue': True},
#                                              'type': 'sport_event'},
#                                 'id': 'sr:sport_event:41763049',
#                                 'sport_event_conditions': {'ground': {'neutral': False}},
#                                 'sport_event_context': {'category': {'country_code': 'ENG',
#                                                                      'id': 'sr:category:1',
#                                                                      'name': 'England'},
#                                                         'competition': {'gender': 'men',
#                                                                         'id': 'sr:competition:17',
#                                                                         'name': 'Premier '
#                                                                                 'League'},
#                                                         'groups': [{'id': 'sr:league:74627',
#                                                                     'name': 'Premier '
#                                                                             'League '
#                                                                             '23/24'}],
#                                                         'round': {'number': 11},
#                                                         'season': {'competition_id': 'sr:competition:17',
#                                                                    'end_date': '2024-05-19',
#                                                                    'id': 'sr:season:105353',
#                                                                    'name': 'Premier '
#                                                                            'League '
#                                                                            '23/24',
#                                                                    'start_date': '2023-08-11',
#                                                                    'year': '23/24'},
#                                                         'sport': {'id': 'sr:sport:1',
#                                                                   'name': 'Soccer'},
#                                                         'stage': {'end_date': '2024-05-19',
#                                                                   'order': 1,
#                                                                   'phase': 'regular '
#                                                                            'season',
#                                                                   'start_date': '2023-08-11',
#                                                                   'type': 'league',
#                                                                   'year': '23/24'}},
#                                 'start_time': '2023-11-05T16:30:00+00:00',
#                                 'start_time_confirmed': True,
#                                 'venue': {'capacity': 10226,
#                                           'city_name': 'Luton',
#                                           'country_code': 'ENG',
#                                           'country_name': 'England',
#                                           'id': 'sr:venue:2178',
#                                           'map_coordinates': '51.884167,-0.431667',
#                                           'name': 'Kenilworth Road',
#                                           'timezone': 'Europe/London'}},
#                 'sport_event_status': {'match_status': 'not_started',
#                                        'status': 'not_started'}},
#                {'sport_event': {'channels': [{'country': 'Sweden',
#                                               'country_code': 'SWE',
#                                               'name': 'V Sport Football HD SE '
#                                                       '- Thor 2/3 (1.0W)',
#                                               'url': 'https://www.allente.se/tv-guide/'},
#                                              {'country': 'United States',
#                                               'country_code': 'USA',
#                                               'name': 'Peacock Premium'}],
#                                 'competitors': [{'abbreviation': 'LIV',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:44',
#                                                  'name': 'Liverpool FC',
#                                                  'qualifier': 'home'},
#                                                 {'abbreviation': 'NFO',
#                                                  'country': 'England',
#                                                  'country_code': 'ENG',
#                                                  'gender': 'male',
#                                                  'id': 'sr:competitor:14',
#                                                  'name': 'Nottingham Forest',
#                                                  'qualifier': 'away'}],
#                                 'coverage': {'sport_event_properties': {'advanced_data': 'live',
#                                                                         'ballspotting': True,
#                                                                         'basic_play_by_play': True,
#                                                                         'basic_player_stats': True,
#                                                                         'basic_team_stats': True,
#                                                                         'commentary': True,
#                                                                         'deeper_play_by_play': True,
#                                                                         'deeper_player_stats': True,
#                                                                         'deeper_team_stats': True,
#                                                                         'fun_facts': True,
#                                                                         'game_clock': True,
#                                                                         'goal_scorers': True,
#                                                                         'lineups': True,
#                                                                         'lineups_availability': 'pre',
#                                                                         'scores': 'live',
#                                                                         'venue': True},
#                                              'type': 'sport_event'},
#                                 'id': 'sr:sport_event:41763033',
#                                 'sport_event_conditions': {'ground': {'neutral': False}},
#                                 'sport_event_context': {'category': {'country_code': 'ENG',
#                                                                      'id': 'sr:category:1',
#                                                                      'name': 'England'},
#                                                         'competition': {'gender': 'men',
#                                                                         'id': 'sr:competition:17',
#                                                                         'name': 'Premier '
#                                                                                 'League'},
#                                                         'groups': [{'id': 'sr:league:74627',
#                                                                     'name': 'Premier '
#                                                                             'League '
#                                                                             '23/24'}],
#                                                         'round': {'number': 10},
#                                                         'season': {'competition_id': 'sr:competition:17',
#                                                                    'end_date': '2024-05-19',
#                                                                    'id': 'sr:season:105353',
#                                                                    'name': 'Premier '
#                                                                            'League '
#                                                                            '23/24',
#                                                                    'start_date': '2023-08-11',
#                                                                    'year': '23/24'},
#                                                         'sport': {'id': 'sr:sport:1',
#                                                                   'name': 'Soccer'},
#                                                         'stage': {'end_date': '2024-05-19',
#                                                                   'order': 1,
#                                                                   'phase': 'regular '
#                                                                            'season',
#                                                                   'start_date': '2023-08-11',
#                                                                   'type': 'league',
#                                                                   'year': '23/24'}},
#                                 'start_time': '2023-10-29T14:00:00+00:00',
#                                 'start_time_confirmed': True,
#                                 'venue': {'capacity': 54074,
#                                           'city_name': 'Liverpool',
#                                           'country_code': 'ENG',
#                                           'country_name': 'England',
#                                           'id': 'sr:venue:579',
#                                           'map_coordinates': '53.430622,-2.960919',
#                                           'name': 'Anfield',
#                                           'timezone': 'Europe/London'}},
#                 'sport_event_status': {'match_status': 'not_started',
#                                        'status': 'not_started'}}]}

# %% [markdown]
# Inspecting the results, we can see that the schedule can be found under the "schedule" key to the top-level dictionary. It is a list of matches, with each match encoded in a dictionary.

# %%
schedule = result["schedules"]
print(type(schedule))
print(len(schedule))
# Out:
# <class 'list'>
# 59

# %% [markdown]
# Each match looks like this:

# %%
pprint(schedule[0]['sport_event']['competitors'])
# Out:
# [{'abbreviation': 'LIV',
#   'country': 'England',
#   'country_code': 'ENG',
#   'gender': 'male',
#   'id': 'sr:competitor:44',
#   'name': 'Liverpool FC',
#   'qualifier': 'home'},
#  {'abbreviation': 'EVE',
#   'country': 'England',
#   'country_code': 'ENG',
#   'gender': 'male',
#   'id': 'sr:competitor:48',
#   'name': 'Everton FC',
#   'qualifier': 'away'}]

# %% [markdown]
# #### 3.2.1.1 Exercise: accessing a soccer schedule
#
# Make a request to the Sportradar Soccer schedule API to obtain the match schedule for Liverpool FC (team_id = sr:competitor:44). Then, from the obtained schedule, make a simple list of fixtures. Your output should be a list with strings as elements. The strings should be of the format "HOME_TEAM vs AWAY_TEAM".

# %%
schedule[0]['sport_event']['competitors']
# Out:
# [{'id': 'sr:competitor:44',
#   'name': 'Liverpool FC',
#   'country': 'England',
#   'country_code': 'ENG',
#   'abbreviation': 'LIV',
#   'qualifier': 'home',
#   'gender': 'male'},
#  {'id': 'sr:competitor:48',
#   'name': 'Everton FC',
#   'country': 'England',
#   'country_code': 'ENG',
#   'abbreviation': 'EVE',
#   'qualifier': 'away',
#   'gender': 'male'}]

# %%
match=schedule[0]['sport_event']['competitors']

match[0]['qualifier']
# Out:
# 'home'

# %%
#pprint(list(schedule[0]['sport_event']['competitors']['qualifier']))

match=schedule[0]['sport_event']['competitors']
game_dic=[]
home_team=''
away_team=''
for teams in match:

    if teams['qualifier']=='home': 
        home_team=teams['name']
    if teams['qualifier']=='away': 
        away_team=teams['name']
    string_format=home_team+' v.s '+away_team
game_dic.append(string_format)
print(game_dic)
# Out:
# ['Liverpool FC v.s Everton FC']

# %% [markdown]
# ### 3.3 Big Tech APIs
#
# Large tech companies make a variety of APIs available for use. Most of these require authentication and can be used to access some very useful data.
#
# #### 3.3.1 Facebook
#
# Facebook has an API called the Graph API that allows a developer to access data about posts, comments, users and more. However, one of the major sticking points of working with APIs from companies like Facebook is that these APIs change very frequently, and sometimes the changes can break a developer's code. Facebook changed their policy towards applications some time ago, and as a result, a developer simply working on a research project is not allowed access to any data from the Graph API. In order to gain data access, all developers must register their application and go through a review process with Facebook. Only then is data collection allowed through the API. These barriers make it hard to discuss and work with the Graph API.
#
# #### 3.3.2 Google
#
# Similarly, Google Maps has a very powerful API that can be used to obtain a large variety of data, however, it is meant to be used as a licensed resource for which developers pay Google a fee. Some of Google's tools may be used for free by obtaining a \$200 API credit, however, this still requires setting up billing. If you are interested in these tools, take a look [here](https://cloud.google.com/maps-platform/pricing/).
#
# An important consideration when working with these APIs is that companies usually enforce a "rate limit". This means a developer is only allowed to make calls under a certain frequency. When you are working with an API from a commercial entity, make sure to check on their rate limit.
#
# #### 3.3.3 Twitter
#
# A big-tech API we can demonstrate and play around with is the Twitter API. While the API can be accessed in a barebones way usings tools such as the `requests` module, we can also use an API client, which is a third-party library that allows us to easily work with an API by automating and simplifying low-level tasks.
#
# For Twitter, we'll use a client called Twython (`pip3 install Twython` to install). First, we'll need to follow these steps to obtain API access and authentication:
#
# 1. Sign up for a Twitter account
# 2. Sign in to [https://apps.twitter.com]
# 3. Create an app
# 4. Go to the API Keys section and click "Generate ACCESS TOKEN".
#
# The resulting keys are:
# - "oauth_access_token"
# - "oauth_access_token_secret"
# - "consumer_key"
# - "consumer_secret"
#
# We'll have to save these values in some variables that we'll need:

# %%
access_token = ''
access_token_secret = ''
consumer_key = ''
consumer_secret = ''

# %% [markdown]
# Now, we'll create a `twitter` object using our consumer key and secret and use this object to download a [list of tweets](https://www.buzzfeed.com/danieldalton/epic-tweet-bro?utm_term=.shgZJEe8V#.lywBJEpjG) using their unique IDs.

# %%
from twython import Twython

twitter = Twython(consumer_key, consumer_secret)

IDlist = [
    "1121915133", 
    "64780730286358528", 
    "64877790624886784", 
    "20", 
    "467192528878329856", 
    "474971393852182528",
    "475071400466972672",
    "475121451511844864",
    "440322224407314432",
    "266031293945503744",
    "3109544383",
    "1895942068",
    "839088619",
    "8062317551",
    "232348380431544320",
    "286910551899127808",
    "286948264236945408",
    "27418932143",
    "786571964",
    "467896522714017792",
    "290892494152028160",
    "470571408896962560"
]

for ID in IDlist:
    status = twitter.show_status(id = ID)
    print(status["text"])
# Out:
# http://twitpic.com/135xa - There's a plane in the Hudson. I'm on the ferry going to pick up the people. Crazy.
# Helicopter hovering above Abbottabad at 1AM (is a rare event).
# So I'm told by a reputable person they have killed Osama Bin Laden. Hot damn.
# just setting up my twttr
# India has won! भारत की विजय। अच्छे दिन आने वाले हैं।
# We can neither confirm nor deny that this is our first tweet.
# Thank you for the @Twitter welcome! We look forward to sharing great #unclassified content with you.
# @CIA We look forward to sharing great classified info about you http://t.co/QcdVxJfU4X https://t.co/kcEwpcitHo More: https://t.co/PEeUpPAt7F
# If only Bradley's arm was longer. Best photo ever. #oscars http://t.co/C9U5NOtGap
# Four more years. http://t.co/bAJE6Vom
# Facebook turned me down. It was a great opportunity to connect with some fantastic people. Looking forward to life's next adventure.
# Got denied by Twitter HQ. That's ok. Would have been a long commute.
# Are you ready to celebrate?  Well, get ready: We have ICE!!!!! Yes, ICE, *WATER ICE* on Mars!  w00t!!!  Best day ever!!
# Hello Twitterverse! We r now LIVE tweeting from the International Space Station -- the 1st live tweet from Space! :) More soon, send your ?s
# I'm safely on the surface of Mars. GALE CRATER I AM IN YOU!!! #MSL
# @Cmdr_Hadfield Are you tweeting from space? MBB
# @WilliamShatner Yes, Standard Orbit, Captain. And we're detecting signs of life on the surface.
# Everest summit! -Sent with @DeLormeGPS Earthmate PN-60w
# Arrested
# Just another night of playing Cards Against Humanity... http://t.co/lfu3YtdHRC
# Ugh - NEVER going to a Ryan Gosling movie in a theater again. Apparently masturbating in the back row is still considered "inappropriate"
# I don't know why I wasn't invited, I'm great at weddings... @KimKardashian @kanyewest

# %% [markdown]
# Next, we'll grab a user's timeline (Drexel University in this case) and print out the last 10 tweets by them:

# %%
drexel_twitter = twitter.get_user_timeline(screen_name = "drexeluniv")

for tweet in drexel_twitter[:10]:
    print(tweet["text"])
    print()
# Out:
# Congratulations to Johnny Zhu, who won first place in the “@ Play” category with his photo “Standing on the Shoulde… https://t.co/19TpUmJGZy
#
# Congratulations to Michelle Kim, who won first place in the “@ Work” category with her photo “Go Metro to the LA Op… https://t.co/k2r0VZtu2V
#
# Thank you to all who participated in the @Steinbright Co-op Photo Contest and sharing your incredible #Drexel co-op… https://t.co/rAkzaAzr6d
#
# Happy Tuesday! Don't forget to swing by EarthFest today between 11:30 a.m. and 1:30 p.m. on Lancaster Walk! 🌎 https://t.co/6oFjgkqdM7
#
# RT @DrexelNow: It's #EarthDay today. Here's how @DrexelUniv is dedicated to transforming its campus into a sustainability leader: https://t…
#
# It’s World Dragon Week at Drexel! 🌎🐉 Join us in celebrating the cultural diversity represented on our campus with e… https://t.co/ImXKWwcmGG
#
# Happy #EarthDay Dragons! Each year, Drexel celebrates its commitment to environmental sustainability with our annua… https://t.co/zMsRNmzIzc
#
# Don't forget to tune into ABC tonight at 10 p.m. EST to see former Drexel lacrosse player Kyle Bergman in the Shark… https://t.co/O4mFyKDnGC
#
# RT @DrexelAdmission: No matter who you are or where you're from, all of us at Drexel are excited to welcome you as one of our own. Hear fro…
#
# This weekend, Drexel graduate Kyle Bergman and his company @swoveralls will be featured on @ABCSharkTank! Watch the… https://t.co/vpx8Ku4jb1

# %% [markdown]
# #### 3.3.3.1 Exercise: access some accidental haikus from Twitter's REST API
# Create your Twitter API keys and download the last 15 tweets by @accidental575 (the hilarious Accidental Haiku Bot).

# %%
# code goes here

# %% [markdown]
# #### 3.3.3.2 Complex queries with filtering
# We can use Twitter's Search API to grab some tweets about a particular topic:

# %%
results = twitter.search(q = '"data science"')
for tweet in results["statuses"]:
    print(tweet["text"])
    print()
# Out:
# https://t.co/br4slRoeTj https://t.co/NSZNAhE9zP
#
# RT @DD_Serena_: Visual Data Storytelling with Tableau (Addison-Wesley Data &amp; Analytics Series) https://t.co/dfjkWwVP8k #Tableau
#
# RT @DD_FaFa_: Visual Data Storytelling with Tableau (Addison-Wesley Data &amp; Analytics Series) https://t.co/w6gvd9Zu5f #Tableau
#
# RT @dataquestio: Dive into our new Data Analyst in R #rstats path:
#
# - Interactive coding in your browser
# - No videos to sit through
# - No pr…
#
# RT @KirkDBorne: New #DataScience 10-page (PDF) Cheat Sheet covers basic concepts in probability, #statistics, statistical learning, #Machin…
#
# RT @DataRubix: Such valid insights by @schmarzo !! The role of critical thinking in #DataScience https://t.co/2YosCuhSZy #DataDriven #DataA…
#
# An interesting list of #DataScience and #ML resources
# https://t.co/YMbiC7CUER
#
# RT @schmarzo: 3 #DesignCanvases that link your business model to #DataScience and #ML initiatives and give #DataScientists direct line of s…
#
# Enterprise Products is hiring in #Houston, TX! Read about our latest #IT job opening via the link in our bio: Specialist, Lead Data Science
#
# RT @wasabi_cloud: According to new research, “#ArtificialIntelligence algorithms coupled with top data science can hunt cancer faster than…
#
# According to new research, “#ArtificialIntelligence algorithms coupled with top data science can hunt cancer faster… https://t.co/9k7TPtopMp
#
# @schmarzo on #CriticalThinking https://t.co/X2gf7BBMGg
#
# RT @Ronald_vanLoon: The Future of #DataScience in One Picture
#  by @granvilledsc @DataScienceCtrl @AnalyticBridge @BoozAllen |
#
# Read more he…
#
# RT @DataScienceFest: Data Science Festival 2019 Video with @TomEwing1979, Senior Data Scientist at Mango Solutions @MangoTheCat
# "6 Things…
#
# RT @spdustin: Holy hell, I'm a glutton for punishment. I've decided to do a whole series of articles on using data science and #NLP to extr…

# %% [markdown]
# #### 3.3.3.3 Twitter's streaming APIs
# he Streaming API lets us collect a portion of all the tweets currently being posted, in real time. This is more complicated than collecting old tweets, because it means essentially downloading an endless stream of data. Let's say we want to collect 30 tweets and stop. We need to write a class based on `TwythonStreamer` that has this failsafe built-in, while also only collecting English tweets:

# %%
from twython import TwythonStreamer

tweets = []

class Streamer(TwythonStreamer):
    
    def on_success(self, data):
        
        if data["lang"] == "en":
            tweets.append(data)
            print("Received tweet #" + str(len(tweets)))
            
        if len(tweets) >= 30:
            self.disconnect()
            
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()

# %% [markdown]
# Next, we need to `Streamer` object and use it to collect tweets. Let's say we want to collect tweets with the keyword "science":

# %%
stream = Streamer(consumer_key, consumer_secret, access_token, access_token_secret)

stream.statuses.filter(track = "science")
# Out:
# Received tweet #1
# Received tweet #2
# Received tweet #3
# Received tweet #4
# Received tweet #5
# Received tweet #6
# Received tweet #7
# Received tweet #8
# Received tweet #9
# Received tweet #10
# Received tweet #11
# Received tweet #12
# Received tweet #13
# Received tweet #14
# Received tweet #15
# Received tweet #16
# Received tweet #17
# Received tweet #18
# Received tweet #19
# Received tweet #20
# Received tweet #21
# Received tweet #22
# Received tweet #23
# Received tweet #24
# Received tweet #25
# Received tweet #26
# Received tweet #27
# Received tweet #28
# Received tweet #29
# Received tweet #30

# %% [markdown]
# Let's take a look at these 30 tweets, collected in real time:

# %%
for tweet in tweets:
    print(tweet["text"])
    print()
# Out:
# All Science: Kuwaiti TV Promotes Homosexuality "Cure" With Suppository That Kills Semen-Eating Anal Worms -… https://t.co/W11KOP8l88
#
# @BobStein_FT This program isn't just for teachers, it is also military and federal employees as an incentive to sta… https://t.co/YI9h7z49cu
#
# Hello @Space_Station from Morrison High School Science Class 285.2 mi away @NASA_Johnson #issabove https://t.co/WMp8SwaoS4
#
# RT @baaaadscience: 90% of what you consist of is undetectable by science.
#
# I've entered to #win two Beaker Creature Reactor Pods from @LRUK with @anywaytostay #competition #win #comp #toys… https://t.co/ISohhwJGnS
#
# LabAnimal: A Nature Research journal covering in vivo science and technology using......
# model organisms of human… https://t.co/nSTEoGy9R5
#
# RT @arstechnica: Listen up: We’ve detected our first marsquake https://t.co/2TocxFQYNU by @SciGuySpace
#
# I redid an ENTIRE science project on my own in elementary bc I hated how my partner and I did it. 💀😂
#
# RT @msalli_: literally in year 9, I would just walk in and my science teacher would just say ‘out’ LOOOOL I hadn’t even done nothing🤣🤣 http…
#
# RT @OliviaLittle: Do you understand how hard it is for me not to cyberbully my political science professor who spends the class monologuing…
#
# RT @AskStacyYoung: #nctevillage looking for science fiction short story and novel suggestions appropriate for YA, featuring characters of c…
#
# “It’s basically science”
#
# RT @JuiceTooWavie: You would not believe Bill Nye
#
# If ten million Science Guys
#
# RT @MickyBell: #EarthDay - This is not science fiction. This is not a film. There is no planet B, we’re not going to colonise the Moon or M…
#
# SIGN    SHARE    --   PM Justin Trudeau; Minister of Science Kirsty Duncan; Health Minister Ginette Petitpas Taylor… https://t.co/0jNyWX7tov
#
# The 8th book on my #2019readingchallenge was "a book about science" and I picked Astrophysics for People in a Hurry… https://t.co/H7J4v6lzar
#
# RT @JuiceTooWavie: You would not believe Bill Nye
#
# If ten million Science Guys
#
# “You don’t listen to the science because you are only interested in solutions that will enable you to carry on like… https://t.co/77P1SmcIJF
#
# RT @SirHenryKau: This 7 month kid draws better than most of us even science can't explain this 😱😱😍 https://t.co/45Blcfy6ui
#
# @AnarchoBoogaloo Historically, stuff like alchemy was just science.
#
# RT @CR_UK: How do tumours ‘know’ where to spread? Read our Science Surgery post for the answer: https://t.co/CqVB1vt6jZ https://t.co/R1divW…
#
# RT @whsource: "in countries such as India, Italy, and the United States, negative attitudes about science appear to have risen in lockstep…
#
# RT @PhiweMkhuzo: PornHub titles are so unnecessarily... "Hot black girl with Degree In Science get Dicked Down by an unemployed man" https:…
#
# RT @oakley_red: Can food allergies be passed on through organ donation?
# It appears there is medical evidence to suggest so. See the case of…
#
# RT @TVMohandasPai: Fear mongering by discredited lying historians, usual behavior, being denied their role of power brokering. Indian acade…
#
# RT @weehalfpintt: Im loving watching grown men shit their frillies over a teen girl talking about science. Its fucking epic.
#
# So... one day the aliens will find Earth and wonder how in the universe anyone survived on a plastic planet? https://t.co/QP8n8TCLQA
#
# These TED Talks are perfect for kiddos excited about science and technology: https://t.co/ARVhqfEBG1
#
# RT @TheLabArtist: First lot of science-themed Pusheen illustrations (astronomer, chemist, geologist and meteorologist)! Going to be making…
#
# InSight has officially detected the first Marsquakes ever! More info here: https://t.co/5m7MoxR6oQ.
#
# Congrats to my… https://t.co/Be1Mm0LYoC

# %% [markdown]
# The Streaming API is a very powerful data source, but it can also generate quite a bit of data in a short period of time. So, whenever you're collecting tweets from the stream, make sure to design the collection in such a way that you don't run out of storage!
